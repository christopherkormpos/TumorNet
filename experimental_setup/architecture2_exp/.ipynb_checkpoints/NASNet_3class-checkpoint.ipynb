# %%
import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import NASNetLarge
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, roc_curve, auc
import seaborn as sns
# Out:
# 2024-10-06 08:40:08.620500: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-06 08:40:08.620542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-06 08:40:08.621929: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-06 08:40:08.629901: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
base_dir = 'Dataset_BUSI_with_GT'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

#Normalization
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#Train,Val and Test sets
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(331, 331),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(331, 331),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(331, 331),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2421 images belonging to 3 classes.
# Found 517 images belonging to 3 classes.
# Found 522 images belonging to 3 classes.

# %%
base_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(331, 331, 3))
# Out:
# 2024-10-06 08:40:17.530749: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31124 MB memory:  -> device: 0, name: Tesla V100-DGXS-32GB, pci bus id: 0000:0f:00.0, compute capability: 7.0

# %%
#Final layers set
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
output_layer = Dense(3, activation='softmax')(x)

# %%
model = Model(inputs=base_model.input, outputs=output_layer)

# %%
#Freeze early layers
for layer in base_model.layers:
    layer.trainable = False
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# Epoch 1/10
# 2024-10-06 08:41:11.173211: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2024-10-06 08:41:14.393323: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fc9b14d2610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-10-06 08:41:14.393357: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-DGXS-32GB, Compute Capability 7.0
# 2024-10-06 08:41:14.407410: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728204074.548435    5552 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 76/76 [==============================] - 88s 622ms/step - loss: 0.8137 - accuracy: 0.6774 - val_loss: 0.5494 - val_accuracy: 0.7485
# Epoch 2/10
# 76/76 [==============================] - 35s 455ms/step - loss: 0.3973 - accuracy: 0.8546 - val_loss: 0.4031 - val_accuracy: 0.8433
# Epoch 3/10
# 76/76 [==============================] - 36s 472ms/step - loss: 0.3123 - accuracy: 0.8786 - val_loss: 0.3873 - val_accuracy: 0.8375
# Epoch 4/10
# 76/76 [==============================] - 36s 466ms/step - loss: 0.2142 - accuracy: 0.9273 - val_loss: 0.3377 - val_accuracy: 0.8762
# Epoch 5/10
# 76/76 [==============================] - 36s 471ms/step - loss: 0.1539 - accuracy: 0.9517 - val_loss: 0.2093 - val_accuracy: 0.9226
# Epoch 6/10
# 76/76 [==============================] - 36s 468ms/step - loss: 0.1082 - accuracy: 0.9698 - val_loss: 0.2409 - val_accuracy: 0.9033
# Epoch 7/10
# 76/76 [==============================] - 36s 475ms/step - loss: 0.0779 - accuracy: 0.9785 - val_loss: 0.2309 - val_accuracy: 0.9207
# Epoch 8/10
# 76/76 [==============================] - 35s 462ms/step - loss: 0.0736 - accuracy: 0.9777 - val_loss: 0.2135 - val_accuracy: 0.9207
# Epoch 9/10
# 76/76 [==============================] - 36s 466ms/step - loss: 0.0505 - accuracy: 0.9884 - val_loss: 0.2211 - val_accuracy: 0.9323
# Epoch 10/10
# 76/76 [==============================] - 35s 462ms/step - loss: 0.0448 - accuracy: 0.9893 - val_loss: 0.2138 - val_accuracy: 0.9304

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# 17/17 [==============================] - 7s 416ms/step - loss: 0.2355 - accuracy: 0.9272
# Test accuracy: 0.9272030591964722

# %%
#Accuracy,Val accuracy, loss and val loss graphs
acc = history.history['accuracy']
val_acc =  history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Accuracy')
plt.plot(epochs_range,val_acc,label="Validation Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Loss')
plt.plot(epochs_range,val_loss,label="Validation Loss")
plt.legend()
plt.show()

# %%
predictions = model.predict(test_generator)
class_predictions = predictions.argmax(axis=1)  # Get the class with the highest probability

# True labels from test generator
true_labels = test_generator.classes

# Display the predicted and true labels
print("Predictions for test data (Predicted, True Label):")
for i in range(len(true_labels)):
    print(f"Predicted: {predictions[i]}, True Label: {true_labels[i]}")
# Out:
# 17/17 [==============================] - 7s 376ms/step
# Predictions for test data (Predicted, True Label):
# Predicted: [9.9999654e-01 3.4219236e-06 1.7315665e-08], True Label: 0
# Predicted: [0.9918024  0.00142966 0.00676796], True Label: 0
# Predicted: [9.9990201e-01 6.1755280e-05 3.6240996e-05], True Label: 0
# Predicted: [9.9877638e-01 1.2229767e-03 6.3139197e-07], True Label: 0
# Predicted: [9.9996471e-01 3.5221467e-05 9.3941601e-08], True Label: 0
# Predicted: [9.9999976e-01 2.6135180e-07 2.3090975e-11], True Label: 0
# Predicted: [9.99999762e-01 2.16815209e-07 1.28850255e-11], True Label: 0
# Predicted: [1.0000000e+00 3.6030144e-11 1.5814269e-09], True Label: 0
# Predicted: [0.65465945 0.31112373 0.03421686], True Label: 0
# Predicted: [9.9999964e-01 3.0786717e-07 7.6337207e-11], True Label: 0
# Predicted: [9.9686050e-01 1.0889291e-05 3.1285686e-03], True Label: 0
# Predicted: [0.71657014 0.17672339 0.10670644], True Label: 0
# Predicted: [0.9242574  0.0011423  0.07460033], True Label: 0
# Predicted: [0.3820676  0.47147194 0.14646044], True Label: 0
# Predicted: [9.99401331e-01 5.98535466e-04 1.06811505e-07], True Label: 0
# Predicted: [0.9965474  0.00179041 0.00166218], True Label: 0
# Predicted: [1.0000000e+00 2.3402753e-09 6.1022856e-13], True Label: 0
# Predicted: [0.82762724 0.00307665 0.16929616], True Label: 0
# Predicted: [9.9999571e-01 4.3103528e-06 2.9527254e-08], True Label: 0
# Predicted: [9.9979204e-01 2.0747368e-04 4.2592742e-07], True Label: 0
# Predicted: [9.9834037e-01 1.6596034e-03 1.1036337e-08], True Label: 0
# Predicted: [7.5866216e-01 2.4133605e-01 1.8173565e-06], True Label: 0
# Predicted: [0.995895   0.0023108  0.00179418], True Label: 0
# Predicted: [0.9935923  0.00453779 0.00186991], True Label: 0
# Predicted: [0.9610768  0.01300669 0.02591653], True Label: 0
# Predicted: [0.9978041  0.00112794 0.00106787], True Label: 0
# Predicted: [1.0000000e+00 1.8627790e-09 1.7215031e-11], True Label: 0
# Predicted: [0.8863245  0.07697077 0.03670469], True Label: 0
# Predicted: [9.9552429e-01 4.3862714e-03 8.9493122e-05], True Label: 0
# Predicted: [9.9920446e-01 7.9556048e-04 1.2197841e-09], True Label: 0
# Predicted: [1.0000000e+00 8.4321883e-13 2.4831364e-16], True Label: 0
# Predicted: [9.9991488e-01 1.7056441e-06 8.3463747e-05], True Label: 0
# Predicted: [9.4140208e-01 5.8576759e-02 2.1215457e-05], True Label: 0
# Predicted: [9.9425733e-01 5.7426370e-03 1.8604659e-09], True Label: 0
# Predicted: [9.9237871e-01 8.6346106e-04 6.7578345e-03], True Label: 0
# Predicted: [7.3707700e-01 2.6292285e-01 1.1778248e-07], True Label: 0
# Predicted: [0.8179416  0.06330516 0.11875322], True Label: 0
# Predicted: [8.067091e-02 9.193261e-01 2.983321e-06], True Label: 0
# Predicted: [0.97214997 0.02686403 0.00098598], True Label: 0
# Predicted: [0.9367211  0.05930358 0.00397532], True Label: 0
# Predicted: [9.9999988e-01 1.1838071e-07 1.0678423e-10], True Label: 0
# Predicted: [9.9999785e-01 2.1865237e-06 1.4288503e-08], True Label: 0
# Predicted: [9.9999785e-01 1.1968678e-08 2.0927005e-06], True Label: 0
# Predicted: [1.5101719e-01 3.8468312e-05 8.4894431e-01], True Label: 0
# Predicted: [9.9999976e-01 2.2092354e-07 5.3776514e-13], True Label: 0
# Predicted: [9.9999976e-01 2.2094628e-07 7.3582024e-10], True Label: 0
# Predicted: [9.999734e-01 2.574436e-05 8.914844e-07], True Label: 0
# Predicted: [9.9769127e-01 2.3086555e-03 6.1454031e-08], True Label: 0
# Predicted: [0.70684695 0.04449669 0.2486563 ], True Label: 0
# Predicted: [9.9999940e-01 5.6803100e-07 2.2878947e-08], True Label: 0
# Predicted: [1.0000000e+00 3.5397357e-10 2.5772513e-16], True Label: 0
# Predicted: [9.99978781e-01 1.34450665e-05 7.74823366e-06], True Label: 0
# Predicted: [9.9998987e-01 9.3684512e-06 6.6080844e-07], True Label: 0
# Predicted: [9.9999738e-01 2.5858892e-06 6.7385124e-09], True Label: 0
# Predicted: [6.5429020e-01 3.4568182e-01 2.7970340e-05], True Label: 0
# Predicted: [1.2731607e-03 9.9862897e-01 9.7901480e-05], True Label: 0
# Predicted: [8.561070e-03 9.963543e-07 9.914380e-01], True Label: 0
# Predicted: [9.9957305e-01 1.9460861e-04 2.3235049e-04], True Label: 0
# Predicted: [0.31956324 0.07226133 0.6081754 ], True Label: 0
# Predicted: [9.9999976e-01 2.5906928e-07 1.4449944e-10], True Label: 0
# Predicted: [9.7297353e-01 2.6975881e-02 5.0583309e-05], True Label: 0
# Predicted: [9.9999964e-01 4.1598693e-07 5.6361465e-10], True Label: 0
# Predicted: [9.9990988e-01 9.0076406e-05 2.5914222e-08], True Label: 0
# Predicted: [1.0000000e+00 2.5040903e-10 3.7265975e-13], True Label: 0
# Predicted: [0.63747853 0.27720934 0.08531213], True Label: 0
# Predicted: [9.9957198e-01 4.2798149e-04 2.7360381e-11], True Label: 0
# Predicted: [0.82833725 0.01233353 0.15932927], True Label: 0
# Predicted: [0.540386   0.4572065  0.00240753], True Label: 0
# Predicted: [9.9998581e-01 1.4175902e-05 3.4064871e-09], True Label: 0
# Predicted: [9.8069865e-01 1.9257316e-02 4.4130931e-05], True Label: 0
# Predicted: [0.59726197 0.37508893 0.0276491 ], True Label: 0
# Predicted: [9.9997973e-01 8.4882340e-06 1.1787398e-05], True Label: 0
# Predicted: [1.0000000e+00 6.9965929e-11 9.8624764e-17], True Label: 0
# Predicted: [1.0000000e+00 2.4022763e-12 4.9177060e-15], True Label: 0
# Predicted: [9.9976593e-01 2.1729158e-04 1.6845615e-05], True Label: 0
# Predicted: [9.9999368e-01 6.1873984e-06 5.9855360e-08], True Label: 0
# Predicted: [9.999999e-01 9.553614e-08 2.981464e-08], True Label: 0
# Predicted: [0.21759234 0.24529293 0.53711474], True Label: 0
# Predicted: [9.9170399e-01 8.2038650e-03 9.2077906e-05], True Label: 0
# Predicted: [0.17676423 0.0223761  0.8008597 ], True Label: 0
# Predicted: [0.95740837 0.03659477 0.0059968 ], True Label: 0
# Predicted: [9.9995661e-01 4.3354539e-05 1.8259747e-08], True Label: 0
# Predicted: [0.89643115 0.09200633 0.01156252], True Label: 0
# Predicted: [9.9997568e-01 2.4339810e-05 2.7797764e-10], True Label: 0
# Predicted: [1.0000000e+00 8.8206657e-15 2.4658918e-15], True Label: 0
# Predicted: [9.9980956e-01 1.8861881e-04 1.7664869e-06], True Label: 0
# Predicted: [0.8638804  0.129988   0.00613162], True Label: 0
# Predicted: [9.9952495e-01 4.7511171e-04 3.3093258e-08], True Label: 0
# Predicted: [9.8934454e-01 1.0655040e-02 3.5373617e-07], True Label: 0
# Predicted: [9.9988365e-01 1.1635733e-04 3.8220382e-08], True Label: 0
# Predicted: [9.9998009e-01 1.9861132e-05 5.7436028e-10], True Label: 0
# Predicted: [9.9999964e-01 3.1292123e-07 1.8037243e-10], True Label: 0
# Predicted: [9.89959300e-01 1.00234235e-02 1.73253902e-05], True Label: 0
# Predicted: [9.8063058e-01 1.9369366e-02 1.1539062e-07], True Label: 0
# Predicted: [9.9958855e-01 4.1076794e-04 6.9180913e-07], True Label: 0
# Predicted: [9.2003864e-01 7.9598129e-02 3.6329526e-04], True Label: 0
# Predicted: [9.9710709e-01 2.8872450e-03 5.6577887e-06], True Label: 0
# Predicted: [9.7080022e-01 6.3761172e-04 2.8562099e-02], True Label: 0
# Predicted: [9.5626360e-01 4.3735262e-02 1.1382668e-06], True Label: 0
# Predicted: [9.9650502e-01 3.4893367e-03 5.6568642e-06], True Label: 0
# Predicted: [9.999254e-01 7.365973e-05 9.169575e-07], True Label: 0
# Predicted: [9.9416202e-01 5.1894705e-03 6.4846297e-04], True Label: 0
# Predicted: [9.9999630e-01 3.6168478e-07 3.3103340e-06], True Label: 0
# Predicted: [9.9994099e-01 5.8994658e-05 4.0027981e-11], True Label: 0
# Predicted: [0.9151491  0.00313348 0.0817174 ], True Label: 0
# Predicted: [9.9983537e-01 1.6440412e-04 2.4310947e-07], True Label: 0
# Predicted: [9.6012980e-01 3.9870251e-02 1.5438525e-08], True Label: 0
# Predicted: [1.000000e+00 1.458672e-09 2.965452e-13], True Label: 0
# Predicted: [9.9892223e-01 8.2875974e-04 2.4897920e-04], True Label: 0
# Predicted: [9.9885750e-01 1.1347606e-03 7.7866016e-06], True Label: 0
# Predicted: [9.9963021e-01 3.6809931e-04 1.6544515e-06], True Label: 0
# Predicted: [0.4967933  0.03084904 0.4723577 ], True Label: 0
# Predicted: [8.4042871e-01 1.5957089e-01 4.4782433e-07], True Label: 0
# Predicted: [0.3350412  0.33043456 0.33452418], True Label: 0
# Predicted: [9.9989605e-01 2.4577179e-05 7.9344114e-05], True Label: 0
# Predicted: [9.971169e-01 2.821185e-03 6.187449e-05], True Label: 0
# Predicted: [9.4133765e-01 1.3360359e-04 5.8528680e-02], True Label: 0
# Predicted: [1.0000000e+00 1.2923912e-12 2.5578649e-11], True Label: 0
# Predicted: [9.7463018e-01 7.2532770e-04 2.4644477e-02], True Label: 0
# Predicted: [9.9598700e-01 3.9833416e-03 2.9721901e-05], True Label: 0
# Predicted: [9.9999928e-01 7.7102641e-07 2.6261937e-11], True Label: 0
# Predicted: [9.9780244e-01 2.4071862e-05 2.1735651e-03], True Label: 0
# Predicted: [0.2638712 0.0141553 0.7219735], True Label: 0
# Predicted: [9.1231728e-01 8.7682739e-02 1.4374761e-08], True Label: 0
# Predicted: [9.9886727e-01 1.0556385e-03 7.7114513e-05], True Label: 0
# Predicted: [0.938677   0.05915957 0.00216348], True Label: 0
# Predicted: [0.91012555 0.01753504 0.07233939], True Label: 0
# Predicted: [0.97286236 0.02535949 0.00177808], True Label: 0
# Predicted: [1.0000000e+00 3.8488216e-11 1.2024458e-13], True Label: 0
# Predicted: [4.2192167e-01 5.7799661e-01 8.1705068e-05], True Label: 0
# Predicted: [0.0693658  0.9287873  0.00184694], True Label: 0
# Predicted: [5.6635905e-02 9.4330728e-01 5.6825989e-05], True Label: 0
# Predicted: [9.0351111e-01 9.6471660e-02 1.7182463e-05], True Label: 0
# Predicted: [0.98600316 0.00368567 0.01031119], True Label: 0
# Predicted: [0.8968019  0.01161687 0.09158119], True Label: 0
# Predicted: [9.9995100e-01 1.1078104e-07 4.8861319e-05], True Label: 0
# Predicted: [9.9999964e-01 3.4774979e-07 5.4863216e-09], True Label: 0
# Predicted: [9.9999797e-01 2.0694251e-06 1.9497641e-13], True Label: 0
# Predicted: [9.9014717e-01 9.8497141e-03 3.0933522e-06], True Label: 0
# Predicted: [9.9999964e-01 3.1301852e-07 2.1404626e-08], True Label: 0
# Predicted: [9.9999893e-01 1.0951638e-06 6.3606580e-13], True Label: 0
# Predicted: [9.9999976e-01 2.3353843e-08 1.9965366e-07], True Label: 0
# Predicted: [9.9999690e-01 3.1138356e-06 6.5956711e-09], True Label: 0
# Predicted: [2.3217764e-01 7.6781785e-01 4.4800613e-06], True Label: 0
# Predicted: [9.9999988e-01 1.3381276e-07 2.0899163e-10], True Label: 0
# Predicted: [9.9999595e-01 4.0283112e-06 1.2351813e-11], True Label: 0
# Predicted: [9.9999893e-01 1.0363682e-06 2.9408305e-08], True Label: 0
# Predicted: [9.9338198e-01 8.6683314e-05 6.5313517e-03], True Label: 0
# Predicted: [9.9894208e-01 2.7176493e-04 7.8619906e-04], True Label: 0
# Predicted: [9.9999988e-01 1.1532445e-07 2.1411499e-11], True Label: 0
# Predicted: [1.35923065e-02 9.86141622e-01 2.65999843e-04], True Label: 0
# Predicted: [0.92619485 0.00292202 0.07088307], True Label: 0
# Predicted: [7.8487152e-01 2.1512669e-01 1.7402358e-06], True Label: 0
# Predicted: [9.6074605e-01 3.9253905e-02 4.7445596e-08], True Label: 0
# Predicted: [3.5207295e-03 9.9647611e-01 3.1492718e-06], True Label: 0
# Predicted: [9.9164385e-01 7.7759046e-03 5.8015174e-04], True Label: 0
# Predicted: [9.9985719e-01 1.2871323e-04 1.4104071e-05], True Label: 0
# Predicted: [7.6877242e-01 2.3122707e-01 5.6738713e-07], True Label: 0
# Predicted: [9.6460462e-01 6.1518227e-04 3.4780208e-02], True Label: 0
# Predicted: [0.98012185 0.01579488 0.00408325], True Label: 0
# Predicted: [9.9999833e-01 1.7023866e-06 1.0332809e-09], True Label: 0
# Predicted: [9.9999964e-01 2.9893286e-07 5.3391441e-12], True Label: 0
# Predicted: [9.9999988e-01 2.5949447e-08 9.8995535e-08], True Label: 0
# Predicted: [9.999999e-01 9.925417e-08 9.183937e-09], True Label: 0
# Predicted: [9.9999952e-01 3.3865194e-07 7.4660903e-08], True Label: 0
# Predicted: [9.9945718e-01 4.6238542e-04 8.0443308e-05], True Label: 0
# Predicted: [0.7161951  0.2588688  0.02493612], True Label: 0
# Predicted: [9.7916025e-01 2.0833205e-02 6.5661357e-06], True Label: 0
# Predicted: [4.688001e-02 9.531199e-01 8.354957e-08], True Label: 0
# Predicted: [9.9995542e-01 4.2963224e-05 1.7048642e-06], True Label: 0
# Predicted: [9.992299e-01 7.691244e-04 9.409885e-07], True Label: 0
# Predicted: [0.01325137 0.9852357  0.00151298], True Label: 0
# Predicted: [9.9971563e-01 2.8428802e-04 6.0608087e-08], True Label: 0
# Predicted: [0.38893485 0.2500868  0.36097834], True Label: 0
# Predicted: [0.03848589 0.08415381 0.87736034], True Label: 0
# Predicted: [9.9999976e-01 2.2572215e-07 3.8852494e-11], True Label: 0
# Predicted: [1.5960732e-02 9.8401874e-01 2.0540134e-05], True Label: 1
# Predicted: [0.20209976 0.5691067  0.22879346], True Label: 1
# Predicted: [0.01563796 0.7717663  0.21259569], True Label: 1
# Predicted: [3.4933326e-01 6.5065104e-01 1.5642274e-05], True Label: 1
# Predicted: [1.8798502e-03 9.9812001e-01 1.2254560e-07], True Label: 1
# Predicted: [0.00703143 0.9746207  0.01834783], True Label: 1
# Predicted: [1.05135456e-04 9.99532938e-01 3.61972605e-04], True Label: 1
# Predicted: [1.5692713e-04 9.9676311e-01 3.0798579e-03], True Label: 1
# Predicted: [0.04162799 0.82218087 0.1361911 ], True Label: 1
# Predicted: [4.1537223e-06 9.9999571e-01 6.8908740e-08], True Label: 1
# Predicted: [7.2405039e-04 9.9898809e-01 2.8782227e-04], True Label: 1
# Predicted: [1.20073915e-08 7.59069371e-06 9.99992371e-01], True Label: 1
# Predicted: [7.4983156e-01 2.5016510e-01 3.2707874e-06], True Label: 1
# Predicted: [0.00369223 0.46231008 0.53399765], True Label: 1
# Predicted: [2.5460406e-04 9.9709237e-01 2.6530249e-03], True Label: 1
# Predicted: [6.2256005e-02 9.3717349e-01 5.7051715e-04], True Label: 1
# Predicted: [0.02197395 0.9485995  0.02942646], True Label: 1
# Predicted: [0.04589783 0.948092   0.00601017], True Label: 1
# Predicted: [1.5596935e-04 9.9983406e-01 9.9029166e-06], True Label: 1
# Predicted: [0.02038573 0.931891   0.0477233 ], True Label: 1
# Predicted: [6.0013817e-03 9.9399191e-01 6.5982881e-06], True Label: 1
# Predicted: [0.5711616  0.37594232 0.05289613], True Label: 1
# Predicted: [3.1677407e-01 6.8322593e-01 3.6774927e-11], True Label: 1
# Predicted: [0.02300414 0.96776253 0.00923337], True Label: 1
# Predicted: [4.8285234e-05 9.9961215e-01 3.3963949e-04], True Label: 1
# Predicted: [8.2096554e-02 9.1750944e-01 3.9400609e-04], True Label: 1
# Predicted: [1.52527455e-05 9.68066156e-01 3.19185480e-02], True Label: 1
# Predicted: [1.0529884e-02 9.8946291e-01 7.1563945e-06], True Label: 1
# Predicted: [7.5571449e-04 9.9923706e-01 7.2596577e-06], True Label: 1
# Predicted: [0.24439631 0.58524567 0.17035797], True Label: 1
# Predicted: [8.4239570e-04 9.9691689e-01 2.2407174e-03], True Label: 1
# Predicted: [0.01585743 0.06552229 0.9186203 ], True Label: 1
# Predicted: [9.5489033e-02 9.0431815e-01 1.9282792e-04], True Label: 1
# Predicted: [9.0171443e-03 9.9098259e-01 1.9452173e-07], True Label: 1
# Predicted: [1.9697179e-06 9.9999785e-01 1.5962011e-07], True Label: 1
# Predicted: [0.25076172 0.7453269  0.00391137], True Label: 1
# Predicted: [7.2256234e-06 9.9999261e-01 8.8691507e-08], True Label: 1
# Predicted: [2.2215263e-03 9.9777728e-01 1.1583107e-06], True Label: 1
# Predicted: [1.9863639e-07 9.9998236e-01 1.7357543e-05], True Label: 1
# Predicted: [1.2272012e-03 9.9876535e-01 7.5484959e-06], True Label: 1
# Predicted: [1.4137518e-01 8.5862482e-01 2.7541558e-09], True Label: 1
# Predicted: [5.6294084e-04 9.9943370e-01 3.3769893e-06], True Label: 1
# Predicted: [2.5269738e-03 9.9735141e-01 1.2162845e-04], True Label: 1
# Predicted: [7.0794264e-04 9.9929178e-01 2.3587972e-07], True Label: 1
# Predicted: [0.00087614 0.812772   0.18635191], True Label: 1
# Predicted: [1.7237445e-02 9.8276246e-01 1.3660780e-07], True Label: 1
# Predicted: [5.5281234e-06 9.9999452e-01 1.4115465e-09], True Label: 1
# Predicted: [0.28317496 0.6692165  0.04760849], True Label: 1
# Predicted: [9.1285998e-05 9.9961436e-01 2.9432683e-04], True Label: 1
# Predicted: [2.1731269e-06 9.9992311e-01 7.4754913e-05], True Label: 1
# Predicted: [6.9220219e-04 9.9930775e-01 1.7057449e-08], True Label: 1
# Predicted: [1.841232e-03 9.979545e-01 2.042238e-04], True Label: 1
# Predicted: [3.3332899e-06 9.9999666e-01 3.2805996e-09], True Label: 1
# Predicted: [6.5207446e-04 9.9934763e-01 1.8341564e-07], True Label: 1
# Predicted: [2.8108373e-06 9.9999714e-01 4.3879202e-09], True Label: 1
# Predicted: [4.7117849e-03 9.9527150e-01 1.6692944e-05], True Label: 1
# Predicted: [1.8420567e-06 9.9999821e-01 3.4171888e-09], True Label: 1
# Predicted: [1.2411621e-03 9.9875569e-01 3.1373768e-06], True Label: 1
# Predicted: [2.1487456e-09 1.0000000e+00 4.1808953e-14], True Label: 1
# Predicted: [2.4891841e-07 9.9999976e-01 6.3977673e-15], True Label: 1
# Predicted: [7.4858978e-02 9.2514104e-01 1.6030981e-08], True Label: 1
# Predicted: [1.5705316e-01 8.4293616e-01 1.0723354e-05], True Label: 1
# Predicted: [1.6941674e-04 9.9983060e-01 2.5798055e-08], True Label: 1
# Predicted: [3.893756e-01 6.102832e-01 3.412089e-04], True Label: 1
# Predicted: [2.2907539e-03 9.9722230e-01 4.8696488e-04], True Label: 1
# Predicted: [1.8502957e-03 9.9814975e-01 1.6435152e-08], True Label: 1
# Predicted: [9.037993e-03 9.909576e-01 4.353590e-06], True Label: 1
# Predicted: [9.9210292e-01 7.8971535e-03 1.3230931e-08], True Label: 1
# Predicted: [6.7812874e-04 9.9932194e-01 9.6856234e-10], True Label: 1
# Predicted: [1.5666544e-02 9.8433334e-01 9.3264894e-08], True Label: 1
# Predicted: [7.7528867e-04 9.9922466e-01 3.0126017e-09], True Label: 1
# Predicted: [1.6301413e-03 9.9836987e-01 1.9688944e-08], True Label: 1
# Predicted: [2.0547323e-04 9.9978882e-01 5.7220705e-06], True Label: 1
# Predicted: [6.847583e-07 9.999987e-01 6.460929e-07], True Label: 1
# Predicted: [3.5403699e-03 9.9632567e-01 1.3399356e-04], True Label: 1
# Predicted: [3.9498966e-02 9.6048695e-01 1.4027322e-05], True Label: 1
# Predicted: [1.3149335e-06 9.9999869e-01 4.1882853e-08], True Label: 1
# Predicted: [4.4006831e-03 9.9559891e-01 4.1090078e-07], True Label: 1
# Predicted: [1.4691518e-05 9.9998510e-01 2.6513342e-07], True Label: 1
# Predicted: [9.229981e-04 9.989899e-01 8.717350e-05], True Label: 1
# Predicted: [4.8091260e-05 9.9995172e-01 2.2046167e-07], True Label: 1
# Predicted: [2.1656703e-03 9.9783427e-01 1.6952367e-07], True Label: 1
# Predicted: [4.7983238e-04 9.9842274e-01 1.0974514e-03], True Label: 1
# Predicted: [0.11664783 0.765461   0.1178911 ], True Label: 1
# Predicted: [4.7738042e-01 5.2245760e-01 1.6196737e-04], True Label: 1
# Predicted: [6.6342478e-04 9.9680954e-01 2.5270476e-03], True Label: 1
# Predicted: [2.8545469e-01 7.1453553e-01 9.7647862e-06], True Label: 1
# Predicted: [1.63495746e-02 9.83638287e-01 1.20469085e-05], True Label: 1
# Predicted: [0.00333736 0.9894471  0.00721557], True Label: 1
# Predicted: [1.8109058e-05 9.9968874e-01 2.9319667e-04], True Label: 1
# Predicted: [2.2900654e-06 9.9999774e-01 2.6630508e-12], True Label: 1
# Predicted: [1.0285866e-02 9.8971248e-01 1.6891685e-06], True Label: 1
# Predicted: [6.8232080e-06 9.9999321e-01 3.5791628e-10], True Label: 1
# Predicted: [1.11651905e-04 9.99888301e-01 9.41571154e-10], True Label: 1
# Predicted: [2.30519450e-03 9.97683883e-01 1.08885515e-05], True Label: 1
# Predicted: [6.436323e-05 9.999356e-01 7.166472e-09], True Label: 1
# Predicted: [4.5729271e-04 9.9910539e-01 4.3733095e-04], True Label: 1
# Predicted: [4.1357757e-04 9.9930036e-01 2.8602552e-04], True Label: 1
# Predicted: [5.7552697e-04 9.9936849e-01 5.5933506e-05], True Label: 1
# Predicted: [1.0887684e-03 9.9891043e-01 8.0478463e-07], True Label: 1
# Predicted: [5.101293e-04 9.994265e-01 6.342685e-05], True Label: 1
# Predicted: [2.9692915e-03 9.9700361e-01 2.7115233e-05], True Label: 1
# Predicted: [2.2647197e-04 9.9976987e-01 3.7506795e-06], True Label: 1
# Predicted: [2.9736594e-04 9.9970263e-01 3.5128433e-08], True Label: 1
# Predicted: [1.2218221e-03 9.9877602e-01 2.1000678e-06], True Label: 1
# Predicted: [1.0344354e-04 9.9989653e-01 7.1048084e-10], True Label: 1
# Predicted: [4.3658484e-04 9.9956340e-01 6.7612418e-09], True Label: 1
# Predicted: [3.9842125e-04 9.9960130e-01 1.9010704e-07], True Label: 1
# Predicted: [8.9627856e-06 9.9998891e-01 2.1642768e-06], True Label: 1
# Predicted: [1.0697646e-02 9.8930079e-01 1.5044448e-06], True Label: 1
# Predicted: [6.575760e-02 9.342389e-01 3.487413e-06], True Label: 1
# Predicted: [1.13021165e-01 8.86978865e-01 3.93189410e-08], True Label: 1
# Predicted: [1.0461365e-02 9.8945671e-01 8.1983941e-05], True Label: 1
# Predicted: [2.4266584e-02 9.7540593e-01 3.2741731e-04], True Label: 1
# Predicted: [1.1596716e-03 9.9884039e-01 3.2911075e-08], True Label: 1
# Predicted: [1.9788120e-05 9.9998021e-01 1.0032658e-12], True Label: 1
# Predicted: [8.5514886e-03 9.9144441e-01 4.1391413e-06], True Label: 1
# Predicted: [1.24747515e-01 8.75244796e-01 7.59449176e-06], True Label: 1
# Predicted: [3.7062354e-04 9.9962592e-01 3.4032082e-06], True Label: 1
# Predicted: [2.4154780e-03 9.9756706e-01 1.7500390e-05], True Label: 1
# Predicted: [8.5183373e-03 9.9147803e-01 3.6146764e-06], True Label: 1
# Predicted: [3.3423305e-01 6.6551751e-01 2.4939681e-04], True Label: 1
# Predicted: [1.8584731e-04 9.9981374e-01 4.2330288e-07], True Label: 1
# Predicted: [8.1654656e-01 1.8341570e-01 3.7812271e-05], True Label: 1
# Predicted: [6.2522507e-01 3.7477085e-01 4.0710615e-06], True Label: 1
# Predicted: [4.0406128e-08 1.0000000e+00 8.6515817e-10], True Label: 1
# Predicted: [4.8152853e-02 9.5184058e-01 6.6187049e-06], True Label: 1
# Predicted: [4.0809420e-04 9.9959117e-01 7.7117795e-07], True Label: 1
# Predicted: [0.05151066 0.82974243 0.11874691], True Label: 1
# Predicted: [3.2117974e-04 9.9967849e-01 3.0253449e-07], True Label: 1
# Predicted: [1.3998222e-04 9.9981946e-01 4.0624520e-05], True Label: 1
# Predicted: [1.3403209e-04 9.9986601e-01 2.9256093e-08], True Label: 1
# Predicted: [2.3981687e-03 9.9749422e-01 1.0767127e-04], True Label: 1
# Predicted: [6.7366683e-04 9.9901009e-01 3.1621227e-04], True Label: 1
# Predicted: [3.3337732e-05 9.9996662e-01 1.8041828e-08], True Label: 1
# Predicted: [4.4768327e-05 9.9995208e-01 3.1231561e-06], True Label: 1
# Predicted: [0.897284   0.10059447 0.00212165], True Label: 1
# Predicted: [1.1616172e-03 9.9883837e-01 1.6611562e-08], True Label: 1
# Predicted: [6.714295e-04 9.992453e-01 8.323455e-05], True Label: 1
# Predicted: [7.1980611e-07 9.9999928e-01 2.9825853e-10], True Label: 1
# Predicted: [1.3072531e-03 9.9868816e-01 4.5886268e-06], True Label: 1
# Predicted: [0.9561154  0.00934806 0.03453649], True Label: 1
# Predicted: [6.4743454e-06 9.9999356e-01 1.3502388e-10], True Label: 1
# Predicted: [9.8711271e-03 9.9011606e-01 1.2754562e-05], True Label: 1
# Predicted: [1.9603482e-04 9.9977380e-01 3.0132089e-05], True Label: 1
# Predicted: [1.7528002e-03 9.9823558e-01 1.1526005e-05], True Label: 1
# Predicted: [2.9392136e-04 9.9945086e-01 2.5517831e-04], True Label: 1
# Predicted: [0.17786503 0.81995517 0.0021798 ], True Label: 1
# Predicted: [0.03371868 0.07748063 0.88880074], True Label: 1
# Predicted: [2.1292353e-05 9.9997866e-01 9.4608179e-09], True Label: 1
# Predicted: [2.9849758e-02 9.7013140e-01 1.8903271e-05], True Label: 1
# Predicted: [2.4420713e-04 9.9975556e-01 2.2136386e-07], True Label: 1
# Predicted: [8.111110e-04 9.982761e-01 9.128115e-04], True Label: 1
# Predicted: [1.8631866e-04 9.9981374e-01 3.5491929e-08], True Label: 1
# Predicted: [2.4051428e-07 9.9999976e-01 1.1551265e-09], True Label: 1
# Predicted: [8.172727e-04 9.991824e-01 2.978676e-07], True Label: 1
# Predicted: [8.7137311e-04 9.9912864e-01 4.9267641e-08], True Label: 1
# Predicted: [2.8636403e-04 9.9948728e-01 2.2635615e-04], True Label: 1
# Predicted: [2.6897498e-04 9.9973089e-01 1.1349287e-07], True Label: 1
# Predicted: [7.7153498e-01 2.2846508e-01 6.6631078e-09], True Label: 1
# Predicted: [5.417931e-03 9.938830e-01 6.990569e-04], True Label: 1
# Predicted: [1.2171648e-03 9.9863547e-01 1.4739520e-04], True Label: 1
# Predicted: [0.0723403  0.43273374 0.49492592], True Label: 1
# Predicted: [7.8390503e-06 9.9999201e-01 6.2773125e-08], True Label: 1
# Predicted: [8.5073715e-04 9.9911445e-01 3.4768291e-05], True Label: 1
# Predicted: [2.8810208e-03 9.9685752e-01 2.6140604e-04], True Label: 1
# Predicted: [0.01714567 0.9613583  0.02149608], True Label: 1
# Predicted: [1.7145647e-03 9.9782699e-01 4.5839802e-04], True Label: 1
# Predicted: [9.6196374e-05 9.9990356e-01 2.5683781e-07], True Label: 1
# Predicted: [1.4655862e-04 9.9985301e-01 3.0256828e-07], True Label: 1
# Predicted: [2.2574279e-03 9.9725807e-01 4.8446684e-04], True Label: 1
# Predicted: [7.5330160e-04 9.9906188e-01 1.8486928e-04], True Label: 1
# Predicted: [6.8174809e-04 9.9799156e-01 1.3266980e-03], True Label: 1
# Predicted: [1.4219171e-06 1.6467848e-05 9.9998212e-01], True Label: 2
# Predicted: [4.0551087e-05 8.3308417e-04 9.9912637e-01], True Label: 2
# Predicted: [0.00128251 0.0085408  0.99017674], True Label: 2
# Predicted: [9.428203e-05 7.825501e-03 9.920803e-01], True Label: 2
# Predicted: [7.2374777e-04 1.5372125e-03 9.9773908e-01], True Label: 2
# Predicted: [3.1179041e-04 1.0123865e-02 9.8956430e-01], True Label: 2
# Predicted: [0.00827578 0.7245742  0.26715004], True Label: 2
# Predicted: [0.00614288 0.00174949 0.99210757], True Label: 2
# Predicted: [1.1536301e-02 7.6892356e-06 9.8845601e-01], True Label: 2
# Predicted: [2.6904210e-05 7.7155506e-05 9.9989593e-01], True Label: 2
# Predicted: [3.1164900e-04 1.8754393e-03 9.9781287e-01], True Label: 2
# Predicted: [5.1102289e-03 6.3148746e-06 9.9488348e-01], True Label: 2
# Predicted: [2.1463844e-05 8.8164386e-05 9.9989033e-01], True Label: 2
# Predicted: [0.01225098 0.03888088 0.9488681 ], True Label: 2
# Predicted: [1.1761967e-04 4.0331674e-05 9.9984205e-01], True Label: 2
# Predicted: [5.307240e-05 3.104887e-03 9.968420e-01], True Label: 2
# Predicted: [4.9536829e-05 1.7357508e-04 9.9977690e-01], True Label: 2
# Predicted: [7.255541e-04 9.770691e-05 9.991767e-01], True Label: 2
# Predicted: [7.2758563e-04 6.7554298e-04 9.9859685e-01], True Label: 2
# Predicted: [2.2595146e-05 1.9963834e-05 9.9995744e-01], True Label: 2
# Predicted: [8.4971740e-05 8.8247566e-07 9.9991417e-01], True Label: 2
# Predicted: [6.4768238e-07 1.2574146e-05 9.9998677e-01], True Label: 2
# Predicted: [1.0652678e-06 1.9824763e-06 9.9999690e-01], True Label: 2
# Predicted: [7.3369971e-04 1.0935430e-03 9.9817276e-01], True Label: 2
# Predicted: [1.6419826e-03 1.2599688e-04 9.9823207e-01], True Label: 2
# Predicted: [5.5229325e-06 4.3278654e-08 9.9999440e-01], True Label: 2
# Predicted: [7.1057329e-05 5.3955466e-02 9.4597346e-01], True Label: 2
# Predicted: [3.4336623e-05 1.7029191e-03 9.9826270e-01], True Label: 2
# Predicted: [0.00334096 0.00272308 0.993936  ], True Label: 2
# Predicted: [5.1448547e-05 2.2972435e-04 9.9971884e-01], True Label: 2
# Predicted: [5.4157849e-06 2.9695643e-06 9.9999166e-01], True Label: 2
# Predicted: [1.3210211e-03 8.5850006e-06 9.9867046e-01], True Label: 2
# Predicted: [1.1192592e-02 8.0232523e-05 9.8872721e-01], True Label: 2
# Predicted: [8.4057648e-04 4.8842680e-06 9.9915457e-01], True Label: 2
# Predicted: [2.8540945e-04 5.4149916e-07 9.9971408e-01], True Label: 2
# Predicted: [2.7515753e-03 4.9293332e-05 9.9719918e-01], True Label: 2
# Predicted: [3.4834369e-04 6.0167786e-04 9.9904996e-01], True Label: 2
# Predicted: [2.7515640e-04 1.9170141e-03 9.9780780e-01], True Label: 2
# Predicted: [1.1085948e-04 4.6671465e-07 9.9988866e-01], True Label: 2
# Predicted: [2.5011404e-04 5.0796545e-04 9.9924195e-01], True Label: 2
# Predicted: [1.2247687e-03 2.5231121e-04 9.9852294e-01], True Label: 2
# Predicted: [3.6411071e-05 2.2706669e-04 9.9973649e-01], True Label: 2
# Predicted: [1.7626781e-04 8.7794790e-05 9.9973589e-01], True Label: 2
# Predicted: [6.1114806e-05 5.6775487e-05 9.9988210e-01], True Label: 2
# Predicted: [0.10632376 0.00164108 0.8920352 ], True Label: 2
# Predicted: [0.00949205 0.22929241 0.7612155 ], True Label: 2
# Predicted: [4.5292806e-03 3.7220371e-04 9.9509853e-01], True Label: 2
# Predicted: [0.3971654  0.01429208 0.5885425 ], True Label: 2
# Predicted: [4.0805554e-03 1.4786143e-04 9.9577159e-01], True Label: 2
# Predicted: [9.5994612e-05 3.7278503e-05 9.9986672e-01], True Label: 2
# Predicted: [1.263893e-04 3.377723e-04 9.995359e-01], True Label: 2
# Predicted: [3.1679787e-03 1.7769706e-06 9.9683028e-01], True Label: 2
# Predicted: [4.6147048e-04 2.9764878e-05 9.9950874e-01], True Label: 2
# Predicted: [1.5280499e-06 6.6350268e-08 9.9999845e-01], True Label: 2
# Predicted: [6.0131788e-05 1.5796482e-04 9.9978191e-01], True Label: 2
# Predicted: [2.1354246e-03 7.6190301e-04 9.9710268e-01], True Label: 2
# Predicted: [0.00094769 0.22178943 0.77726287], True Label: 2
# Predicted: [6.656050e-05 9.679902e-03 9.902535e-01], True Label: 2
# Predicted: [1.1165321e-03 5.2836145e-05 9.9883062e-01], True Label: 2
# Predicted: [2.2388524e-01 4.7816557e-04 7.7563661e-01], True Label: 2
# Predicted: [0.00511869 0.00215593 0.9927254 ], True Label: 2
# Predicted: [8.5275795e-05 4.0107749e-05 9.9987459e-01], True Label: 2
# Predicted: [1.2402707e-03 8.6694869e-04 9.9789280e-01], True Label: 2
# Predicted: [2.0501418e-03 7.7384274e-04 9.9717605e-01], True Label: 2
# Predicted: [4.5681003e-04 7.4621785e-04 9.9879694e-01], True Label: 2
# Predicted: [1.3743917e-03 2.2098975e-06 9.9862337e-01], True Label: 2
# Predicted: [1.6288973e-02 1.0256488e-04 9.8360842e-01], True Label: 2
# Predicted: [1.4820124e-02 1.3237486e-04 9.8504746e-01], True Label: 2
# Predicted: [1.1222743e-02 1.7221066e-05 9.8876011e-01], True Label: 2
# Predicted: [1.3031477e-02 4.9737297e-05 9.8691875e-01], True Label: 2
# Predicted: [1.7586297e-04 6.8395973e-05 9.9975580e-01], True Label: 2
# Predicted: [0.00542807 0.5270583  0.4675136 ], True Label: 2
# Predicted: [1.1117796e-04 1.4982223e-07 9.9988866e-01], True Label: 2
# Predicted: [1.383440e-03 5.000000e-04 9.981166e-01], True Label: 2
# Predicted: [7.8072007e-05 3.1951722e-04 9.9960238e-01], True Label: 2
# Predicted: [1.18886834e-04 2.53180933e-05 9.99855757e-01], True Label: 2
# Predicted: [5.0730258e-04 1.3725090e-08 9.9949265e-01], True Label: 2
# Predicted: [5.5503505e-03 2.7682470e-05 9.9442202e-01], True Label: 2
# Predicted: [1.3789180e-02 1.5030993e-04 9.8606050e-01], True Label: 2
# Predicted: [1.6001573e-02 2.1572833e-07 9.8399818e-01], True Label: 2
# Predicted: [1.2742137e-04 2.4699196e-03 9.9740261e-01], True Label: 2
# Predicted: [2.087260e-03 7.929526e-04 9.971198e-01], True Label: 2
# Predicted: [2.3377997e-04 4.7552870e-03 9.9501097e-01], True Label: 2
# Predicted: [1.0989730e-04 1.5338313e-05 9.9987471e-01], True Label: 2
# Predicted: [0.00755287 0.0029533  0.98949385], True Label: 2
# Predicted: [3.2365145e-04 1.6019480e-04 9.9951613e-01], True Label: 2
# Predicted: [9.4358873e-04 6.3303407e-05 9.9899310e-01], True Label: 2
# Predicted: [5.0610900e-03 8.5977212e-05 9.9485296e-01], True Label: 2
# Predicted: [8.840091e-03 5.035714e-04 9.906563e-01], True Label: 2
# Predicted: [4.0780343e-03 1.7382179e-06 9.9592018e-01], True Label: 2
# Predicted: [5.357776e-05 3.385213e-04 9.996080e-01], True Label: 2
# Predicted: [3.2719917e-04 9.6147170e-04 9.9871135e-01], True Label: 2
# Predicted: [6.4173655e-05 1.5653121e-04 9.9977928e-01], True Label: 2
# Predicted: [1.6066299e-03 4.3576671e-04 9.9795759e-01], True Label: 2
# Predicted: [0.00649381 0.12271114 0.870795  ], True Label: 2
# Predicted: [0.01865094 0.05842989 0.92291915], True Label: 2
# Predicted: [0.9769155  0.00235633 0.0207282 ], True Label: 2
# Predicted: [0.01586179 0.8577446  0.1263936 ], True Label: 2
# Predicted: [0.00667089 0.58859897 0.4047301 ], True Label: 2
# Predicted: [1.0500496e-04 9.0889167e-03 9.9080604e-01], True Label: 2
# Predicted: [0.01028465 0.0916272  0.8980882 ], True Label: 2
# Predicted: [1.4626308e-04 3.7789423e-02 9.6206427e-01], True Label: 2
# Predicted: [0.00307605 0.00154268 0.99538136], True Label: 2
# Predicted: [0.0102386  0.00508679 0.9846746 ], True Label: 2
# Predicted: [0.00660558 0.4726758  0.52071863], True Label: 2
# Predicted: [0.01155739 0.62612456 0.362318  ], True Label: 2
# Predicted: [0.00907022 0.11863855 0.87229127], True Label: 2
# Predicted: [0.3035681  0.19750445 0.4989275 ], True Label: 2
# Predicted: [1.9071286e-04 1.3289737e-04 9.9967635e-01], True Label: 2
# Predicted: [2.5540667e-03 8.4763251e-06 9.9743748e-01], True Label: 2
# Predicted: [2.2360018e-05 2.4748870e-05 9.9995291e-01], True Label: 2
# Predicted: [1.3780606e-04 1.7354223e-04 9.9968863e-01], True Label: 2
# Predicted: [3.5193855e-06 5.3570060e-05 9.9994290e-01], True Label: 2
# Predicted: [2.6369223e-04 1.6632737e-09 9.9973625e-01], True Label: 2
# Predicted: [4.0843296e-03 1.4351614e-05 9.9590129e-01], True Label: 2
# Predicted: [2.2385774e-04 6.1006369e-03 9.9367553e-01], True Label: 2
# Predicted: [4.7906997e-05 4.9365357e-05 9.9990273e-01], True Label: 2
# Predicted: [2.3583741e-05 3.1771309e-05 9.9994469e-01], True Label: 2
# Predicted: [1.3403706e-05 3.7839776e-04 9.9960822e-01], True Label: 2
# Predicted: [2.0076975e-04 9.1852620e-03 9.9061394e-01], True Label: 2
# Predicted: [0.00155508 0.02989354 0.9685514 ], True Label: 2
# Predicted: [0.01139658 0.00862894 0.9799745 ], True Label: 2
# Predicted: [1.380333e-03 2.994663e-08 9.986197e-01], True Label: 2
# Predicted: [2.4725955e-02 4.7606905e-04 9.7479790e-01], True Label: 2
# Predicted: [0.02722156 0.01840639 0.9543721 ], True Label: 2
# Predicted: [5.4765085e-04 1.2089578e-02 9.8736274e-01], True Label: 2
# Predicted: [3.5227864e-04 3.1231641e-05 9.9961650e-01], True Label: 2
# Predicted: [5.6336585e-02 4.7308681e-06 9.4365871e-01], True Label: 2
# Predicted: [7.7786149e-07 1.4135391e-06 9.9999785e-01], True Label: 2
# Predicted: [9.4825239e-04 6.4205515e-06 9.9904531e-01], True Label: 2
# Predicted: [5.2019078e-03 3.1800366e-05 9.9476624e-01], True Label: 2
# Predicted: [1.8321300e-05 2.6622158e-04 9.9971539e-01], True Label: 2
# Predicted: [2.2436961e-06 2.2276045e-05 9.9997544e-01], True Label: 2
# Predicted: [7.2728464e-05 1.1751735e-05 9.9991548e-01], True Label: 2
# Predicted: [2.8456129e-02 4.5287237e-05 9.7149861e-01], True Label: 2
# Predicted: [1.9945692e-04 1.4018794e-03 9.9839860e-01], True Label: 2
# Predicted: [1.4345159e-02 7.5743155e-04 9.8489743e-01], True Label: 2
# Predicted: [1.8045853e-03 1.4384696e-07 9.9819523e-01], True Label: 2
# Predicted: [4.0781301e-06 3.6092345e-06 9.9999237e-01], True Label: 2
# Predicted: [6.4363485e-05 1.3228935e-05 9.9992239e-01], True Label: 2
# Predicted: [2.0285859e-05 2.9796010e-04 9.9968183e-01], True Label: 2
# Predicted: [0.08231698 0.01301163 0.9046714 ], True Label: 2
# Predicted: [0.02625318 0.07325175 0.9004951 ], True Label: 2
# Predicted: [6.1049133e-05 1.1344334e-05 9.9992764e-01], True Label: 2
# Predicted: [1.3729533e-04 8.1575752e-07 9.9986184e-01], True Label: 2
# Predicted: [0.5587998  0.00066462 0.44053555], True Label: 2
# Predicted: [0.05557908 0.14967573 0.7947452 ], True Label: 2
# Predicted: [1.3877013e-02 3.7539303e-06 9.8611927e-01], True Label: 2
# Predicted: [0.00107706 0.00342324 0.9954997 ], True Label: 2
# Predicted: [1.3309688e-05 3.6880902e-08 9.9998665e-01], True Label: 2
# Predicted: [5.4503128e-02 7.3646952e-04 9.4476038e-01], True Label: 2
# Predicted: [3.7743922e-03 3.4126770e-04 9.9588436e-01], True Label: 2
# Predicted: [0.00929752 0.00285739 0.9878451 ], True Label: 2
# Predicted: [0.29215628 0.24514611 0.46269763], True Label: 2
# Predicted: [0.06918937 0.22683784 0.70397276], True Label: 2
# Predicted: [0.00748861 0.02205578 0.97045565], True Label: 2
# Predicted: [3.1837821e-03 4.4993678e-05 9.9677116e-01], True Label: 2
# Predicted: [1.0484266e-03 2.0551024e-04 9.9874604e-01], True Label: 2
# Predicted: [2.2161175e-03 7.9487305e-04 9.9698907e-01], True Label: 2
# Predicted: [0.31594348 0.00283055 0.68122596], True Label: 2
# Predicted: [1.7266233e-03 5.3047720e-06 9.9826801e-01], True Label: 2
# Predicted: [7.9686003e-04 2.1927156e-04 9.9898380e-01], True Label: 2
# Predicted: [0.00229778 0.02660177 0.9711004 ], True Label: 2
# Predicted: [1.9171082e-05 7.5514537e-05 9.9990535e-01], True Label: 2
# Predicted: [7.7595678e-04 6.4690206e-03 9.9275500e-01], True Label: 2
# Predicted: [4.7115715e-05 7.2454463e-06 9.9994564e-01], True Label: 2
# Predicted: [3.6088354e-03 9.8457793e-04 9.9540663e-01], True Label: 2
# Predicted: [5.5304215e-05 1.2636332e-04 9.9981838e-01], True Label: 2
# Predicted: [0.02314978 0.04048894 0.9363613 ], True Label: 2
# Predicted: [0.00126478 0.11643684 0.88229835], True Label: 2
# Predicted: [0.00301055 0.32437703 0.6726124 ], True Label: 2
# Predicted: [4.5371661e-04 1.3464389e-02 9.8608196e-01], True Label: 2
# Predicted: [0.00200138 0.00853637 0.9894623 ], True Label: 2

# %%
cm = confusion_matrix(true_labels, class_predictions)

class_labels = ['Benign', 'Malignant', 'Normal']

# Plot confusion matrix using heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
class_predictions = predictions.argmax(axis=1)  # Predicted classes

# True labels from test generator (already done in previous step)
true_labels = test_generator.classes

# Compute confusion matrix
cm = confusion_matrix(true_labels, class_predictions)

# Initialize arrays for precision, recall, and F1 score
precision = []
recall = []
f1_score = []

# Calculate Precision, Recall, and F1 Score for each class
for i in range(len(cm)):
    # True Positives (TP): diagonal element
    TP = cm[i, i]
    
    # False Positives (FP): sum of column i, excluding TP
    FP = sum(cm[:, i]) - TP
    
    # False Negatives (FN): sum of row i, excluding TP
    FN = sum(cm[i, :]) - TP
    
    # Precision = TP / (TP + FP)
    prec = TP / (TP + FP) if (TP + FP) > 0 else 0
    precision.append(prec)
    
    # Recall (Sensitivity) = TP / (TP + FN)
    rec = TP / (TP + FN) if (TP + FN) > 0 else 0
    recall.append(rec)
    
    # F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
    f1 = 2 * (prec * rec) / (prec + rec) if (prec + rec) > 0 else 0
    f1_score.append(f1)

# Convert lists to numpy arrays for easier manipulation
precision = np.array(precision)
recall = np.array(recall)
f1_score = np.array(f1_score)

# Display the results for each class
for i in range(len(cm)):
    print(f"Class {i} - Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1-Score: {f1_score[i]:.4f}")
# Out:
# Class 0 - Precision: 0.9405, Recall: 0.8977, F1-Score: 0.9186
# Class 1 - Precision: 0.9091, Recall: 0.9249, F1-Score: 0.9169
# Class 2 - Precision: 0.9326, Recall: 0.9595, F1-Score: 0.9459
