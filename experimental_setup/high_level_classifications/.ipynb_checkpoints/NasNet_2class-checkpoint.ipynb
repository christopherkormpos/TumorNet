# %%
import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import NASNetLarge
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, roc_curve, auc
import seaborn as sns
# Out:
# 2024-11-04 16:18:39.040330: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9373] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-04 16:18:39.040368: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-04 16:18:39.041836: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1534] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-04 16:18:39.049965: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
base_dir = '../final_dataset1'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
#Normalization
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#Train,Val and Test sets
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(331, 331),
    batch_size=32,
    class_mode='binary',
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(331, 331),
    batch_size=32,
    class_mode='binary',
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(331, 331),
    batch_size=32,
    class_mode='binary',
    shuffle=False,
)
# Out:
# Found 4865 images belonging to 2 classes.
# Found 1042 images belonging to 2 classes.
# Found 1043 images belonging to 2 classes.

# %%
base_model = NASNetLarge(weights='imagenet', include_top=False, input_shape=(331, 331, 3))
# Out:
# 2024-11-04 16:18:43.926576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31124 MB memory:  -> device: 0, name: Tesla V100-DGXS-32GB, pci bus id: 0000:0f:00.0, compute capability: 7.0

# %%
#Final layers set
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
output_layer = Dense(1, activation='sigmoid')(x)

# %%
model = Model(inputs=base_model.input, outputs=output_layer)

# %%
#Freeze early layers
for layer in base_model.layers:
    layer.trainable = False
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=5,
    validation_data=val_generator
)
# Out:
# Epoch 1/5
# 2024-11-04 16:19:37.782045: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:467] Loaded cuDNN version 90100
# 2024-11-04 16:19:41.449340: I external/local_xla/xla/service/service.cc:168] XLA service 0x7f3d3f587870 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-11-04 16:19:41.449366: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-DGXS-32GB, Compute Capability 7.0
# 2024-11-04 16:19:41.456089: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730737181.551461   12205 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 153/153 [==============================] - 120s 510ms/step - loss: 0.0343 - accuracy: 0.9866 - val_loss: 0.0044 - val_accuracy: 0.9981
# Epoch 2/5
# 153/153 [==============================] - 66s 429ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0017 - val_accuracy: 0.9990
# Epoch 3/5
# 153/153 [==============================] - 66s 429ms/step - loss: 0.0054 - accuracy: 0.9977 - val_loss: 0.0035 - val_accuracy: 0.9981
# Epoch 4/5
# 153/153 [==============================] - 66s 431ms/step - loss: 1.6018e-04 - accuracy: 1.0000 - val_loss: 0.0015 - val_accuracy: 0.9990
# Epoch 5/5
# 153/153 [==============================] - 65s 423ms/step - loss: 4.5582e-05 - accuracy: 1.0000 - val_loss: 8.6090e-04 - val_accuracy: 0.9990

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# 33/33 [==============================] - 13s 398ms/step - loss: 7.7856e-04 - accuracy: 1.0000
# Test accuracy: 1.0

# %%
#Accuracy,Val accuracy, loss and val loss graphs
acc = history.history['accuracy']
val_acc =  history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(5)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Accuracy')
plt.plot(epochs_range,val_acc,label="Validation Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Loss')
plt.plot(epochs_range,val_loss,label="Validation Loss")
plt.legend()
plt.show()

# %%
predictions = model.predict(test_generator)
binary_predictions = (predictions > 0.5).astype(int).flatten()

true_labels = test_generator.classes
# Out:
# 33/33 [==============================] - 22s 359ms/step

# %%
#Confussion matrix
cm = confusion_matrix(true_labels, binary_predictions)

#Confusion matrix plot
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Breast Ultrasounds', 'Irrelevant Images'], yticklabels=['Breast Ultrasounds', 'Irrelevant Images'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
model.save('nasnet')
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f985fccdd20>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# INFO:tensorflow:Assets written to: nasnet/assets
# INFO:tensorflow:Assets written to: nasnet/assets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.save('nasnet')
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103, in Model.save(self, filepath, overwrite, save_format, **kwargs)
#    3049 @traceback_utils.filter_traceback
#    3050 def save(self, filepath, overwrite=True, save_format=None, **kwargs):
#    3051     """Saves a model as a TensorFlow SavedModel or HDF5 file.
#    3052
#    3053     See the [Serialization and Saving guide](
#    (...)
#    3101     Note that `model.save()` is an alias for `tf.keras.models.save_model()`.
#    3102     """
# -> 3103     saving_api.save_model(
#    3104         self,
#    3105         filepath=filepath,
#    3106         overwrite=overwrite,
#    3107         save_format=save_format,
#    3108         **kwargs,
#    3109     )
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_api.py:167, in save_model(model, filepath, overwrite, save_format, **kwargs)
#     164     saving_lib.save_model(model, filepath)
#     165 else:
#     166     # Legacy case
# --> 167     return legacy_sm_saving_lib.save_model(
#     168         model,
#     169         filepath,
#     170         overwrite=overwrite,
#     171         save_format=save_format,
#     172         **kwargs,
#     173     )
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/saving/legacy/save.py:168, in save_model(model, filepath, overwrite, include_optimizer, save_format, signatures, options, save_traces)
#     164 with serialization.SharedObjectSavingScope():
#     165     with keras_option_scope(
#     166         save_traces=save_traces, in_tf_saved_model_scope=True
#     167     ):
# --> 168         saved_model_save.save(
#     169             model,
#     170             filepath,
#     171             overwrite,
#     172             include_optimizer,
#     173             signatures,
#     174             options,
#     175             save_traces,
#     176         )
#
# File /usr/local/lib/python3.10/dist-packages/keras/src/saving/legacy/saved_model/save.py:98, in save(model, filepath, overwrite, include_optimizer, signatures, options, save_traces)
#      96 with backend.deprecated_internal_learning_phase_scope(0):
#      97     with utils.keras_option_scope(save_traces):
# ---> 98         saved_nodes, node_paths = save_lib.save_and_return_nodes(
#      99             model, filepath, signatures, options
#     100         )
#     102     # Save all metadata to a separate file in the SavedModel directory.
#     103     metadata = generate_keras_metadata(saved_nodes, node_paths)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/saved_model/save.py:1412, in save_and_return_nodes(obj, export_dir, signatures, options, experimental_skip_checkpoint)
#    1407 else:
#    1408   path = file_io.join(
#    1409       compat.as_str(export_dir),
#    1410       compat.as_str(constants.SAVED_MODEL_FILENAME_PB))
#    1411   file_io.atomic_write_string_to_file(
# -> 1412       path, saved_model.SerializeToString(deterministic=True))
#    1413   fingerprinting_utils.write_fingerprint(export_dir)
#    1415 # Save debug info, if requested.
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1077, in _AddSerializeToStringMethod.<locals>.SerializeToString(self, **kwargs)
#    1073 if not self.IsInitialized():
#    1074   raise message_mod.EncodeError(
#    1075       'Message %s is missing required fields: %s' % (
#    1076       self.DESCRIPTOR.full_name, ','.join(self.FindInitializationErrors())))
# -> 1077 return self.SerializePartialToString(**kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1086, in _AddSerializePartialToStringMethod.<locals>.SerializePartialToString(self, **kwargs)
#    1084 def SerializePartialToString(self, **kwargs):
#    1085   out = BytesIO()
# -> 1086   self._InternalSerialize(out.write, **kwargs)
#    1087   return out.getvalue()
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1109, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 for field_descriptor, field_value in self.ListFields():
#    1108   _MaybeAddEncoder(cls, field_descriptor)
# -> 1109   field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1110 for tag_bytes, value_bytes in self._unknown_fields:
#    1111   write_bytes(tag_bytes)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/encoder.py:739, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     737 write(tag)
#     738 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 739 element._InternalSerialize(write, deterministic)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1109, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 for field_descriptor, field_value in self.ListFields():
#    1108   _MaybeAddEncoder(cls, field_descriptor)
# -> 1109   field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1110 for tag_bytes, value_bytes in self._unknown_fields:
#    1111   write_bytes(tag_bytes)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/encoder.py:745, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     743 write(tag)
#     744 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 745 return value._InternalSerialize(write, deterministic)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1109, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 for field_descriptor, field_value in self.ListFields():
#    1108   _MaybeAddEncoder(cls, field_descriptor)
# -> 1109   field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1110 for tag_bytes, value_bytes in self._unknown_fields:
#    1111   write_bytes(tag_bytes)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/encoder.py:745, in MessageEncoder.<locals>.EncodeField(write, value, deterministic)
#     743 write(tag)
#     744 local_EncodeVarint(write, value.ByteSize(), deterministic)
# --> 745 return value._InternalSerialize(write, deterministic)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1109, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 for field_descriptor, field_value in self.ListFields():
#    1108   _MaybeAddEncoder(cls, field_descriptor)
# -> 1109   field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1110 for tag_bytes, value_bytes in self._unknown_fields:
#    1111   write_bytes(tag_bytes)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/encoder.py:739, in MessageEncoder.<locals>.EncodeRepeatedField(write, value, deterministic)
#     737 write(tag)
#     738 local_EncodeVarint(write, element.ByteSize(), deterministic)
# --> 739 element._InternalSerialize(write, deterministic)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:1109, in _AddSerializePartialToStringMethod.<locals>.InternalSerialize(self, write_bytes, deterministic)
#    1107 for field_descriptor, field_value in self.ListFields():
#    1108   _MaybeAddEncoder(cls, field_descriptor)
# -> 1109   field_descriptor._encoder(write_bytes, field_value, deterministic)
#    1110 for tag_bytes, value_bytes in self._unknown_fields:
#    1111   write_bytes(tag_bytes)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/encoder.py:803, in MapEncoder.<locals>.EncodeField(write, value, deterministic)
#     801 value_keys = sorted(value.keys()) if deterministic else value
#     802 for key in value_keys:
# --> 803   entry_msg = message_type._concrete_class(key=key, value=value[key])
#     804   encode_message(write, entry_msg, deterministic)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:555, in _AddInitMethod.<locals>.init(self, **kwargs)
#     553   field_value = _GetIntegerEnumValue(field.enum_type, field_value)
#     554 try:
# --> 555   setattr(self, field_name, field_value)
#     556 except TypeError:
#     557   _ReraiseTypeErrorWithFieldName(message_descriptor.name, field_name)
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/python_message.py:696, in _AddPropertiesForNonRepeatedScalarField.<locals>.field_setter(self, new_value)
#     691 def field_setter(self, new_value):
#     692   # pylint: disable=protected-access
#     693   # Testing the value for truthiness captures all of the proto3 defaults
#     694   # (0, 0.0, enum 0, and False).
#     695   try:
# --> 696     new_value = type_checker.CheckValue(new_value)
#     697   except TypeError as e:
#     698     raise TypeError(
#     699         'Cannot set %s to %.1024r: %s' % (field.full_name, new_value, e))
#
# File /usr/local/lib/python3.10/dist-packages/google/protobuf/internal/type_checkers.py:134, in IntValueChecker.CheckValue(self, proposed_value)
#     130 class IntValueChecker(object):
#     132   """Checker used for integer fields.  Performs type-check and range check."""
# --> 134   def CheckValue(self, proposed_value):
#     135     if not hasattr(proposed_value, '__index__') or (
#     136         type(proposed_value).__module__ == 'numpy' and
#     137         type(proposed_value).__name__ == 'ndarray'):
#     138       message = ('%.1024r has type %s, but expected one of: %s' %
#     139                  (proposed_value, type(proposed_value), (int,)))
#
# KeyboardInterrupt:

# %%
from keras.preprocessing import image
def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(331,331))  # Adjust target size as needed
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalize pixel values
    return img_array

def predict_single_image(model, image_path):
    processed_image = preprocess_image(image_path)
    prediction = model.predict(processed_image)
    return prediction

# %%
image_path = '../final_dataset1/breast_ultrasounds/benign (6).png'  # Replace with the actual image filename
prediction = predict_single_image(model, image_path)
prediction

# %%
def get_model():
    global model
    model = load_model('nasnet')
    print("Model loaded successfully!")

# %%
from keras.models import load_model
def preprocess_image(image, target_size=(331, 331)):
    if image.mode != "RGB":
        image = image.convert("RGB")
    image = image.resize(target_size)
    img_array = img_to_array(image)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0
    return img_array

print("Loading Keras model...")
get_model()
# Out:
# Loading Keras model...
# 2024-10-20 11:30:02.803766: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1926] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 31124 MB memory:  -> device: 0, name: Tesla V100-DGXS-32GB, pci bus id: 0000:0f:00.0, compute capability: 7.0
# Model loaded successfully!

# %%
from keras.preprocessing import image
def preprocess_image(image_path):
    img = image.load_img(image_path, target_size=(331,331)) #djust target size as needed
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array /= 255.0  # Normalize pixel values
    return img_array

def predict_single_image(model, image_path):
    processed_image = preprocess_image(image_path)
    prediction = model.predict(processed_image)
    return prediction

# %%
image_path = './car.jpg'  # Replace with the actual image filename
prediction = predict_single_image(model, image_path)
prediction
# Out:
# 1/1 [==============================] - 0s 83ms/step
# array([[0.9999993]], dtype=float32)
