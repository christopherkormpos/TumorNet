# %%
import os
import shutil
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, roc_curve, auc
import seaborn as sns

# %%
base_dir = 'Dataset_BUSI_with_GT'
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')
test_dir = os.path.join(base_dir, 'test')

# %%
#Normalization
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

#Train,Val and Test sets
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(229, 229),
    batch_size=32,
    class_mode='categorical'
)

val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size=(229, 229),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(229, 229),
    batch_size=32,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 2421 images belonging to 3 classes.
# Found 517 images belonging to 3 classes.
# Found 522 images belonging to 3 classes.

# %%
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(229, 229, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 3s 0us/step

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
output_layer = Dense(3, activation='softmax')(x)

# %%
model = Model(inputs=base_model.input, outputs=output_layer)

# %%
#Freeze early layers
for layer in base_model.layers:
    layer.trainable = False

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=10,
    validation_data=val_generator
)
# Out:
# Epoch 1/10
# 76/76 [==============================] - 43s 424ms/step - loss: 0.9508 - accuracy: 0.6758 - val_loss: 0.6325 - val_accuracy: 0.7524
# Epoch 2/10
# 76/76 [==============================] - 29s 378ms/step - loss: 0.5011 - accuracy: 0.8021 - val_loss: 0.4890 - val_accuracy: 0.7892
# Epoch 3/10
# 76/76 [==============================] - 29s 377ms/step - loss: 0.3954 - accuracy: 0.8397 - val_loss: 0.4260 - val_accuracy: 0.8298
# Epoch 4/10
# 76/76 [==============================] - 29s 378ms/step - loss: 0.3167 - accuracy: 0.8835 - val_loss: 0.4437 - val_accuracy: 0.8085
# Epoch 5/10
# 76/76 [==============================] - 28s 373ms/step - loss: 0.2717 - accuracy: 0.9005 - val_loss: 0.3461 - val_accuracy: 0.8627
# Epoch 6/10
# 76/76 [==============================] - 28s 364ms/step - loss: 0.2161 - accuracy: 0.9223 - val_loss: 0.4019 - val_accuracy: 0.8317
# Epoch 7/10
# 76/76 [==============================] - 29s 378ms/step - loss: 0.1749 - accuracy: 0.9385 - val_loss: 0.3666 - val_accuracy: 0.8588
# Epoch 8/10
# 76/76 [==============================] - 28s 366ms/step - loss: 0.1361 - accuracy: 0.9579 - val_loss: 0.2942 - val_accuracy: 0.8859
# Epoch 9/10
# 76/76 [==============================] - 28s 373ms/step - loss: 0.0840 - accuracy: 0.9793 - val_loss: 0.2807 - val_accuracy: 0.9014
# Epoch 10/10
# 76/76 [==============================] - 29s 380ms/step - loss: 0.0593 - accuracy: 0.9893 - val_loss: 0.2681 - val_accuracy: 0.9033

# %%
test_loss, test_acc = model.evaluate(test_generator)
print(f'Test accuracy: {test_acc}')
# Out:
# 17/17 [==============================] - 6s 326ms/step - loss: 0.2826 - accuracy: 0.9061
# Test accuracy: 0.9061302542686462

# %%
#Accuracy,Val accuracy, loss and val loss graphs
acc = history.history['accuracy']
val_acc =  history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(10)

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.plot(epochs_range,acc,label='Accuracy')
plt.plot(epochs_range,val_acc,label="Validation Accuracy")
plt.legend()

plt.subplot(1,2,2)
plt.plot(epochs_range,loss,label='Loss')
plt.plot(epochs_range,val_loss,label="Validation Loss")
plt.legend()
plt.show()

# %%
predictions = model.predict(test_generator)
class_predictions = predictions.argmax(axis=1)  # Get the class with the highest probability

# True labels from test generator
true_labels = test_generator.classes

# Display the predicted and true labels
print("Predictions for test data (Predicted, True Label):")
for i in range(len(true_labels)):
    print(f"Predicted: {predictions[i]}, True Label: {true_labels[i]}")
# Out:
# 17/17 [==============================] - 8s 305ms/step
# Predictions for test data (Predicted, True Label):
# Predicted: [9.9999988e-01 1.1028447e-07 3.2221130e-09], True Label: 0
# Predicted: [0.9509304  0.047483   0.00158657], True Label: 0
# Predicted: [0.98602897 0.00828537 0.00568558], True Label: 0
# Predicted: [0.98467225 0.00863909 0.00668861], True Label: 0
# Predicted: [9.9999964e-01 3.8348503e-07 4.0144504e-10], True Label: 0
# Predicted: [9.9999785e-01 2.1383248e-06 5.7870948e-11], True Label: 0
# Predicted: [9.9999988e-01 7.0620430e-08 3.4204386e-11], True Label: 0
# Predicted: [1.0000000e+00 5.7382046e-08 3.3595079e-10], True Label: 0
# Predicted: [0.57558304 0.39487344 0.02954353], True Label: 0
# Predicted: [9.9439174e-01 5.6082965e-03 4.7748658e-09], True Label: 0
# Predicted: [0.91767275 0.0681934  0.01413386], True Label: 0
# Predicted: [0.72881895 0.08915232 0.18202873], True Label: 0
# Predicted: [0.5091066  0.15360434 0.3372891 ], True Label: 0
# Predicted: [0.9402001  0.0153416  0.04445835], True Label: 0
# Predicted: [4.2286381e-01 5.7713544e-01 7.2355863e-07], True Label: 0
# Predicted: [0.9247244  0.07107859 0.00419703], True Label: 0
# Predicted: [1.0000000e+00 3.5537882e-09 3.0064618e-14], True Label: 0
# Predicted: [9.9537402e-01 4.4509955e-03 1.7499353e-04], True Label: 0
# Predicted: [9.8504132e-01 1.4773394e-02 1.8526592e-04], True Label: 0
# Predicted: [9.5179641e-01 4.8203260e-02 3.6140756e-07], True Label: 0
# Predicted: [9.99438107e-01 5.61838504e-04 1.23260255e-08], True Label: 0
# Predicted: [9.6360642e-01 3.6359522e-02 3.4077930e-05], True Label: 0
# Predicted: [0.9780492  0.02024534 0.00170539], True Label: 0
# Predicted: [0.7833005  0.21475115 0.00194835], True Label: 0
# Predicted: [9.7371644e-01 2.6244683e-02 3.8925129e-05], True Label: 0
# Predicted: [9.99888659e-01 1.11242334e-04 7.05483671e-08], True Label: 0
# Predicted: [9.8897856e-01 1.0997745e-02 2.3722265e-05], True Label: 0
# Predicted: [0.6798827  0.30842873 0.01168856], True Label: 0
# Predicted: [9.7942907e-01 2.0544937e-02 2.6089763e-05], True Label: 0
# Predicted: [9.9987650e-01 1.2335903e-04 7.2379905e-08], True Label: 0
# Predicted: [9.9999583e-01 4.1781482e-06 2.9604289e-08], True Label: 0
# Predicted: [9.7137272e-01 2.8504791e-02 1.2255364e-04], True Label: 0
# Predicted: [0.96990067 0.02069542 0.00940392], True Label: 0
# Predicted: [6.8472987e-01 3.1478819e-01 4.8194017e-04], True Label: 0
# Predicted: [0.9335093  0.04807383 0.01841692], True Label: 0
# Predicted: [0.537942   0.45852166 0.00353641], True Label: 0
# Predicted: [0.8270684  0.07000443 0.1029272 ], True Label: 0
# Predicted: [7.6202971e-01 2.3792675e-01 4.3498214e-05], True Label: 0
# Predicted: [8.8688970e-01 1.1282415e-01 2.8620794e-04], True Label: 0
# Predicted: [5.6936443e-01 4.3057868e-01 5.6928398e-05], True Label: 0
# Predicted: [9.9996316e-01 3.6820205e-05 3.8671017e-09], True Label: 0
# Predicted: [9.8943686e-01 4.9621583e-04 1.0066925e-02], True Label: 0
# Predicted: [0.96401    0.03302522 0.00296484], True Label: 0
# Predicted: [0.22646414 0.11790546 0.65563047], True Label: 0
# Predicted: [9.9999988e-01 1.1059813e-07 9.7772464e-11], True Label: 0
# Predicted: [9.6570086e-01 3.4298882e-02 2.2211157e-07], True Label: 0
# Predicted: [9.9998748e-01 1.2564362e-05 3.9851340e-08], True Label: 0
# Predicted: [9.9997294e-01 2.6899917e-05 1.6280373e-07], True Label: 0
# Predicted: [0.28870422 0.00526249 0.7060333 ], True Label: 0
# Predicted: [9.9999988e-01 5.1317670e-08 7.0800084e-08], True Label: 0
# Predicted: [9.9982220e-01 1.7767613e-04 9.6821495e-08], True Label: 0
# Predicted: [9.7514421e-01 2.4818953e-02 3.6818528e-05], True Label: 0
# Predicted: [9.992330e-01 7.663884e-04 6.122645e-07], True Label: 0
# Predicted: [9.9965882e-01 3.4110487e-04 1.1940004e-07], True Label: 0
# Predicted: [9.8585874e-01 1.4117363e-02 2.3903465e-05], True Label: 0
# Predicted: [0.25342718 0.6825577  0.06401514], True Label: 0
# Predicted: [3.6710536e-01 4.3393517e-04 6.3246065e-01], True Label: 0
# Predicted: [9.9460298e-01 5.3619533e-03 3.5057416e-05], True Label: 0
# Predicted: [9.9966836e-01 3.0166990e-04 3.0065676e-05], True Label: 0
# Predicted: [9.9989760e-01 1.0237948e-04 3.2853606e-08], True Label: 0
# Predicted: [0.85566014 0.14347215 0.00086779], True Label: 0
# Predicted: [9.9999106e-01 8.8588413e-06 6.2286354e-08], True Label: 0
# Predicted: [9.9917978e-01 7.9989317e-04 2.0417261e-05], True Label: 0
# Predicted: [9.9994445e-01 1.0417294e-05 4.5202829e-05], True Label: 0
# Predicted: [0.14852773 0.51919997 0.33227232], True Label: 0
# Predicted: [3.8847730e-01 6.1152238e-01 3.8655162e-07], True Label: 0
# Predicted: [0.45521033 0.24589328 0.29889637], True Label: 0
# Predicted: [0.22406453 0.70358384 0.07235169], True Label: 0
# Predicted: [9.9943262e-01 5.6721206e-04 1.5196385e-07], True Label: 0
# Predicted: [0.95115566 0.03432664 0.01451765], True Label: 0
# Predicted: [9.9912637e-01 6.5871503e-04 2.1481351e-04], True Label: 0
# Predicted: [9.9654609e-01 2.9332435e-03 5.2064558e-04], True Label: 0
# Predicted: [9.9998546e-01 1.4553579e-05 4.8855817e-09], True Label: 0
# Predicted: [9.9999928e-01 7.0424710e-07 2.0602021e-08], True Label: 0
# Predicted: [9.9998987e-01 1.0078870e-05 2.7856080e-09], True Label: 0
# Predicted: [9.999999e-01 9.658023e-09 7.184756e-08], True Label: 0
# Predicted: [9.9995732e-01 4.1661606e-05 1.0662523e-06], True Label: 0
# Predicted: [0.93873477 0.02236771 0.03889743], True Label: 0
# Predicted: [9.5908839e-01 4.0911142e-02 5.0671326e-07], True Label: 0
# Predicted: [0.9504975  0.01396749 0.03553504], True Label: 0
# Predicted: [0.57523745 0.42362428 0.00113827], True Label: 0
# Predicted: [9.9993753e-01 6.1908082e-05 5.7113380e-07], True Label: 0
# Predicted: [9.018036e-01 9.811816e-02 7.830410e-05], True Label: 0
# Predicted: [9.9999213e-01 7.9044758e-06 1.4332906e-09], True Label: 0
# Predicted: [9.9999976e-01 1.5583186e-07 1.4056488e-07], True Label: 0
# Predicted: [9.6759552e-01 3.2102708e-02 3.0176414e-04], True Label: 0
# Predicted: [9.7945684e-01 1.9581655e-02 9.6152973e-04], True Label: 0
# Predicted: [9.9983120e-01 1.5117139e-04 1.7639015e-05], True Label: 0
# Predicted: [9.8871791e-01 1.1281325e-02 7.8254226e-07], True Label: 0
# Predicted: [9.4188851e-01 5.8101464e-02 9.9994741e-06], True Label: 0
# Predicted: [9.9999475e-01 5.0317785e-06 2.6994923e-07], True Label: 0
# Predicted: [9.9760002e-01 2.3994753e-03 5.2400833e-07], True Label: 0
# Predicted: [9.9794048e-01 2.0527586e-03 6.7538285e-06], True Label: 0
# Predicted: [9.5363766e-01 4.6348769e-02 1.3505362e-05], True Label: 0
# Predicted: [0.8878321  0.10796891 0.00419897], True Label: 0
# Predicted: [9.9910897e-01 5.1677384e-04 3.7425233e-04], True Label: 0
# Predicted: [9.9384189e-01 6.1579887e-03 9.3286467e-08], True Label: 0
# Predicted: [9.9787676e-01 1.9194024e-03 2.0393445e-04], True Label: 0
# Predicted: [9.8265636e-01 1.7343542e-02 9.5676590e-08], True Label: 0
# Predicted: [0.07481874 0.92094785 0.00423346], True Label: 0
# Predicted: [9.9596655e-01 3.9407448e-03 9.2682298e-05], True Label: 0
# Predicted: [0.97260654 0.02449423 0.00289916], True Label: 0
# Predicted: [9.9998534e-01 1.4720721e-05 1.3056651e-08], True Label: 0
# Predicted: [9.9826497e-01 1.7346415e-03 3.4937611e-07], True Label: 0
# Predicted: [9.9350923e-01 5.5457344e-03 9.4503560e-04], True Label: 0
# Predicted: [8.2521677e-01 1.7477544e-01 7.8039347e-06], True Label: 0
# Predicted: [9.8515075e-01 1.4847058e-02 2.1791896e-06], True Label: 0
# Predicted: [1.0000000e+00 2.6577633e-09 2.3613839e-10], True Label: 0
# Predicted: [9.6376592e-01 3.6193103e-02 4.0967894e-05], True Label: 0
# Predicted: [0.9073697  0.08360477 0.00902559], True Label: 0
# Predicted: [0.91593176 0.08031487 0.00375332], True Label: 0
# Predicted: [0.6664226  0.29531416 0.03826323], True Label: 0
# Predicted: [9.2878914e-01 7.1153961e-02 5.6894169e-05], True Label: 0
# Predicted: [0.9535062  0.0366351  0.00985872], True Label: 0
# Predicted: [0.881084   0.11191572 0.00700025], True Label: 0
# Predicted: [0.9114924  0.08746631 0.00104124], True Label: 0
# Predicted: [9.8132402e-01 2.2840565e-04 1.8447638e-02], True Label: 0
# Predicted: [9.9999940e-01 1.3039370e-07 5.1138176e-07], True Label: 0
# Predicted: [0.8759484  0.12264416 0.00140743], True Label: 0
# Predicted: [9.7708595e-01 2.2811856e-02 1.0231689e-04], True Label: 0
# Predicted: [9.9730682e-01 2.6927770e-03 3.4722106e-07], True Label: 0
# Predicted: [0.21969232 0.7789534  0.00135432], True Label: 0
# Predicted: [9.7149211e-01 7.4044854e-04 2.7767433e-02], True Label: 0
# Predicted: [2.9441628e-01 7.0558327e-01 5.3905961e-07], True Label: 0
# Predicted: [9.6973354e-01 3.0123493e-02 1.4295911e-04], True Label: 0
# Predicted: [0.65542203 0.3377249  0.00685306], True Label: 0
# Predicted: [8.3783323e-01 1.6167788e-01 4.8888766e-04], True Label: 0
# Predicted: [9.1754675e-01 8.2298793e-02 1.5441875e-04], True Label: 0
# Predicted: [9.9999952e-01 4.5765188e-07 6.6261455e-11], True Label: 0
# Predicted: [0.6621754  0.30672902 0.03109556], True Label: 0
# Predicted: [6.4279240e-01 3.5703442e-01 1.7315517e-04], True Label: 0
# Predicted: [0.8669861  0.11937992 0.01363397], True Label: 0
# Predicted: [8.9369011e-01 1.0557047e-01 7.3939731e-04], True Label: 0
# Predicted: [0.97784245 0.0172468  0.00491077], True Label: 0
# Predicted: [9.9995375e-01 3.7945996e-05 8.3110535e-06], True Label: 0
# Predicted: [9.9994648e-01 5.1562100e-05 1.9575682e-06], True Label: 0
# Predicted: [9.9173075e-01 5.8849895e-04 7.6807132e-03], True Label: 0
# Predicted: [8.3645713e-01 1.6354287e-01 3.2337106e-09], True Label: 0
# Predicted: [9.9969041e-01 3.0810546e-04 1.5427421e-06], True Label: 0
# Predicted: [1.0000000e+00 8.1412992e-09 1.5095945e-10], True Label: 0
# Predicted: [9.9999964e-01 3.1700412e-07 4.8408649e-10], True Label: 0
# Predicted: [9.9999857e-01 1.4779722e-06 1.4876021e-08], True Label: 0
# Predicted: [9.9319321e-01 6.8066437e-03 6.4315493e-08], True Label: 0
# Predicted: [9.084174e-01 9.151092e-02 7.170400e-05], True Label: 0
# Predicted: [9.9875820e-01 1.2417743e-03 5.7990771e-08], True Label: 0
# Predicted: [9.9994576e-01 5.3940243e-05 2.2675938e-07], True Label: 0
# Predicted: [9.9950075e-01 4.9921300e-04 2.4729241e-08], True Label: 0
# Predicted: [9.9797136e-01 2.0286196e-03 1.6535971e-08], True Label: 0
# Predicted: [9.6537805e-01 6.9892482e-04 3.3923093e-02], True Label: 0
# Predicted: [9.9999952e-01 4.2249016e-07 5.2472544e-11], True Label: 0
# Predicted: [1.3307980e-04 9.9816483e-01 1.7021718e-03], True Label: 0
# Predicted: [0.17681928 0.012624   0.8105567 ], True Label: 0
# Predicted: [0.89351314 0.10255916 0.00392758], True Label: 0
# Predicted: [9.9761140e-01 2.3879188e-03 7.3431391e-07], True Label: 0
# Predicted: [0.00906136 0.98790026 0.00303835], True Label: 0
# Predicted: [9.9583626e-01 4.1636829e-03 1.8970190e-09], True Label: 0
# Predicted: [9.9262118e-01 7.3786299e-03 1.3906713e-07], True Label: 0
# Predicted: [9.9631459e-01 3.6706582e-03 1.4721730e-05], True Label: 0
# Predicted: [0.823951   0.11977587 0.05627308], True Label: 0
# Predicted: [0.45469773 0.04227773 0.5030245 ], True Label: 0
# Predicted: [9.9999976e-01 2.7741484e-07 9.5118793e-09], True Label: 0
# Predicted: [9.991179e-01 8.810796e-04 9.580651e-07], True Label: 0
# Predicted: [9.9989557e-01 1.0425615e-04 1.3409517e-07], True Label: 0
# Predicted: [9.9996138e-01 3.8394093e-05 2.2994239e-07], True Label: 0
# Predicted: [6.6237700e-01 3.3716416e-01 4.5886019e-04], True Label: 0
# Predicted: [9.9998105e-01 1.7983468e-05 9.5022642e-07], True Label: 0
# Predicted: [9.8644340e-01 1.2852966e-02 7.0372008e-04], True Label: 0
# Predicted: [8.91078889e-01 1.08920984e-01 1.23321712e-07], True Label: 0
# Predicted: [9.6245104e-01 3.7548821e-02 7.5778175e-08], True Label: 0
# Predicted: [8.5867888e-01 1.4118573e-01 1.3543019e-04], True Label: 0
# Predicted: [9.9960953e-01 3.9044136e-04 5.1720552e-09], True Label: 0
# Predicted: [0.84971756 0.13378997 0.01649239], True Label: 0
# Predicted: [9.9984908e-01 7.0950162e-05 7.9948186e-05], True Label: 0
# Predicted: [0.54592407 0.45055202 0.00352393], True Label: 0
# Predicted: [9.5669961e-01 4.3252196e-02 4.8217527e-05], True Label: 0
# Predicted: [9.9245656e-01 7.5406153e-03 2.8091306e-06], True Label: 0
# Predicted: [4.7825880e-02 9.5189577e-01 2.7835887e-04], True Label: 1
# Predicted: [0.19873647 0.78734577 0.01391767], True Label: 1
# Predicted: [0.13773872 0.84801495 0.01424631], True Label: 1
# Predicted: [2.3269425e-03 9.9766278e-01 1.0176469e-05], True Label: 1
# Predicted: [3.9815725e-04 9.9959797e-01 3.8937819e-06], True Label: 1
# Predicted: [0.34178126 0.65712696 0.00109181], True Label: 1
# Predicted: [1.0964507e-03 9.9821031e-01 6.9326069e-04], True Label: 1
# Predicted: [7.2670387e-05 9.9991393e-01 1.3359917e-05], True Label: 1
# Predicted: [4.9773374e-05 9.9994004e-01 1.0160776e-05], True Label: 1
# Predicted: [2.1848719e-01 7.8144926e-01 6.3548876e-05], True Label: 1
# Predicted: [1.2179926e-03 9.9878162e-01 3.3105707e-07], True Label: 1
# Predicted: [2.1457508e-05 1.0470917e-01 8.9526939e-01], True Label: 1
# Predicted: [4.8126765e-03 9.9518234e-01 5.0290569e-06], True Label: 1
# Predicted: [8.2055916e-04 9.4532746e-01 5.3852089e-02], True Label: 1
# Predicted: [0.01237663 0.97741663 0.01020665], True Label: 1
# Predicted: [3.5534360e-02 9.6444440e-01 2.1294927e-05], True Label: 1
# Predicted: [0.70107245 0.28565532 0.01327226], True Label: 1
# Predicted: [0.07348908 0.7725128  0.15399814], True Label: 1
# Predicted: [6.1721867e-04 9.9899036e-01 3.9241996e-04], True Label: 1
# Predicted: [0.02640364 0.9202025  0.0533939 ], True Label: 1
# Predicted: [6.4839780e-02 9.3514389e-01 1.6412918e-05], True Label: 1
# Predicted: [0.22023968 0.7529737  0.0267866 ], True Label: 1
# Predicted: [9.4966165e-04 9.9899548e-01 5.4932567e-05], True Label: 1
# Predicted: [0.00210902 0.99665976 0.00123128], True Label: 1
# Predicted: [0.13988623 0.78456694 0.07554683], True Label: 1
# Predicted: [6.569871e-02 9.342328e-01 6.850811e-05], True Label: 1
# Predicted: [0.03375104 0.9525838  0.01366515], True Label: 1
# Predicted: [1.7601046e-03 9.9768651e-01 5.5343512e-04], True Label: 1
# Predicted: [3.7217043e-02 9.6243155e-01 3.5147299e-04], True Label: 1
# Predicted: [0.02338089 0.9739985  0.00262057], True Label: 1
# Predicted: [3.7199315e-03 9.9569905e-01 5.8097579e-04], True Label: 1
# Predicted: [0.5089902  0.47911474 0.01189502], True Label: 1
# Predicted: [0.85796624 0.14078926 0.00124448], True Label: 1
# Predicted: [0.0025856  0.9948821  0.00253233], True Label: 1
# Predicted: [0.0213194  0.9258969  0.05278379], True Label: 1
# Predicted: [4.1298019e-03 9.9546599e-01 4.0417002e-04], True Label: 1
# Predicted: [0.00501563 0.03402014 0.9609642 ], True Label: 1
# Predicted: [2.6139582e-04 9.9973565e-01 2.9394705e-06], True Label: 1
# Predicted: [3.0914107e-05 9.9996889e-01 2.7769266e-07], True Label: 1
# Predicted: [4.4240168e-04 9.9791843e-01 1.6391109e-03], True Label: 1
# Predicted: [4.7265245e-03 9.9527341e-01 1.3050899e-07], True Label: 1
# Predicted: [6.8437598e-06 9.9999094e-01 2.2352626e-06], True Label: 1
# Predicted: [2.1935866e-04 9.8525572e-01 1.4524929e-02], True Label: 1
# Predicted: [1.1965910e-06 9.9999821e-01 6.1163405e-07], True Label: 1
# Predicted: [0.2780061  0.7186604  0.00333342], True Label: 1
# Predicted: [2.1075683e-02 9.7883135e-01 9.2940369e-05], True Label: 1
# Predicted: [2.3167822e-04 9.9976820e-01 6.1686237e-08], True Label: 1
# Predicted: [0.21877842 0.60280395 0.17841768], True Label: 1
# Predicted: [9.3183284e-05 9.9976808e-01 1.3867144e-04], True Label: 1
# Predicted: [2.8272317e-04 9.9737525e-01 2.3419987e-03], True Label: 1
# Predicted: [4.7589533e-04 9.9952400e-01 1.1081381e-07], True Label: 1
# Predicted: [6.5229801e-03 9.9331057e-01 1.6650755e-04], True Label: 1
# Predicted: [3.1746482e-04 9.9968231e-01 2.6183653e-07], True Label: 1
# Predicted: [0.01207432 0.9842988  0.00362694], True Label: 1
# Predicted: [1.5045468e-05 9.9998498e-01 1.9726061e-08], True Label: 1
# Predicted: [0.10135578 0.8906368  0.00800737], True Label: 1
# Predicted: [4.2074989e-05 9.9995553e-01 2.4161322e-06], True Label: 1
# Predicted: [1.5340641e-03 9.9846554e-01 5.1383802e-07], True Label: 1
# Predicted: [1.8719905e-03 9.9812800e-01 4.6169163e-08], True Label: 1
# Predicted: [5.3000934e-03 9.9469972e-01 1.8434324e-07], True Label: 1
# Predicted: [0.36552146 0.63100076 0.00347777], True Label: 1
# Predicted: [1.8079552e-01 8.1917864e-01 2.5838839e-05], True Label: 1
# Predicted: [0.2675673  0.7195185  0.01291417], True Label: 1
# Predicted: [9.4366288e-03 9.9055952e-01 3.7762566e-06], True Label: 1
# Predicted: [7.5573516e-03 9.9231017e-01 1.3251150e-04], True Label: 1
# Predicted: [2.3533386e-04 9.9974364e-01 2.0927602e-05], True Label: 1
# Predicted: [1.6878414e-01 8.3121282e-01 3.0845974e-06], True Label: 1
# Predicted: [9.5969516e-01 3.9744403e-02 5.6050182e-04], True Label: 1
# Predicted: [1.3959321e-02 9.8603976e-01 9.3519873e-07], True Label: 1
# Predicted: [5.5074761e-05 9.9994457e-01 3.0112295e-07], True Label: 1
# Predicted: [1.6473385e-02 9.8351836e-01 8.2044417e-06], True Label: 1
# Predicted: [3.4342724e-01 6.5647954e-01 9.3218448e-05], True Label: 1
# Predicted: [2.3375873e-02 9.7660929e-01 1.4842192e-05], True Label: 1
# Predicted: [2.5117086e-04 9.9969590e-01 5.2890380e-05], True Label: 1
# Predicted: [7.7800392e-03 9.9218726e-01 3.2589654e-05], True Label: 1
# Predicted: [5.8736037e-03 9.9408025e-01 4.6088506e-05], True Label: 1
# Predicted: [6.3571257e-05 9.9993515e-01 1.2784218e-06], True Label: 1
# Predicted: [1.1596823e-04 9.9988329e-01 7.6103163e-07], True Label: 1
# Predicted: [1.6100846e-02 9.8387653e-01 2.2686072e-05], True Label: 1
# Predicted: [0.14579944 0.8491266  0.00507396], True Label: 1
# Predicted: [1.5969741e-03 9.9839836e-01 4.5982674e-06], True Label: 1
# Predicted: [2.5250912e-03 9.9738806e-01 8.6969994e-05], True Label: 1
# Predicted: [0.00184674 0.9775894  0.02056379], True Label: 1
# Predicted: [5.1141502e-03 9.9474335e-01 1.4250982e-04], True Label: 1
# Predicted: [0.6664945  0.33200997 0.00149555], True Label: 1
# Predicted: [0.09281141 0.8887884  0.01840024], True Label: 1
# Predicted: [3.6915711e-01 6.3073707e-01 1.0577181e-04], True Label: 1
# Predicted: [7.5422838e-02 9.2453057e-01 4.6574401e-05], True Label: 1
# Predicted: [6.4899670e-03 9.9349976e-01 1.0250655e-05], True Label: 1
# Predicted: [3.9496116e-02 9.5968229e-01 8.2149444e-04], True Label: 1
# Predicted: [1.3217641e-02 9.8675704e-01 2.5294714e-05], True Label: 1
# Predicted: [6.4570934e-04 9.9924433e-01 1.0994790e-04], True Label: 1
# Predicted: [4.9094474e-03 9.9508518e-01 5.3166614e-06], True Label: 1
# Predicted: [1.1107006e-02 9.8858440e-01 3.0864036e-04], True Label: 1
# Predicted: [7.8573258e-04 9.9910849e-01 1.0573945e-04], True Label: 1
# Predicted: [8.602749e-03 9.913892e-01 8.042618e-06], True Label: 1
# Predicted: [0.00596384 0.97145826 0.02257798], True Label: 1
# Predicted: [4.0786415e-03 9.9588335e-01 3.8020615e-05], True Label: 1
# Predicted: [0.08902655 0.87500006 0.03597337], True Label: 1
# Predicted: [1.7715538e-02 9.8226869e-01 1.5826832e-05], True Label: 1
# Predicted: [1.0959616e-04 9.9909580e-01 7.9463160e-04], True Label: 1
# Predicted: [0.15660809 0.8403422  0.00304968], True Label: 1
# Predicted: [3.1914948e-05 9.9996090e-01 7.1602012e-06], True Label: 1
# Predicted: [3.6352531e-03 9.9603146e-01 3.3325522e-04], True Label: 1
# Predicted: [0.32686642 0.66708696 0.0060466 ], True Label: 1
# Predicted: [2.8757905e-03 9.9710816e-01 1.5992100e-05], True Label: 1
# Predicted: [6.8820475e-05 9.9993122e-01 5.4340557e-08], True Label: 1
# Predicted: [1.4500021e-02 9.8549795e-01 1.9918446e-06], True Label: 1
# Predicted: [0.01103813 0.9869676  0.00199428], True Label: 1
# Predicted: [0.02607579 0.9706523  0.00327198], True Label: 1
# Predicted: [4.0464842e-01 5.9533042e-01 2.1140328e-05], True Label: 1
# Predicted: [1.5799940e-02 9.8419631e-01 3.8126068e-06], True Label: 1
# Predicted: [7.5044576e-03 9.9249434e-01 1.2029733e-06], True Label: 1
# Predicted: [7.1548557e-01 2.8436044e-01 1.5405293e-04], True Label: 1
# Predicted: [3.568660e-03 9.964270e-01 4.419204e-06], True Label: 1
# Predicted: [1.5927037e-03 9.9840587e-01 1.4343107e-06], True Label: 1
# Predicted: [5.9536803e-03 9.9394327e-01 1.0311873e-04], True Label: 1
# Predicted: [9.4525117e-01 5.4673456e-02 7.5357537e-05], True Label: 1
# Predicted: [0.01392974 0.9636324  0.02243792], True Label: 1
# Predicted: [0.189374   0.80876005 0.00186593], True Label: 1
# Predicted: [0.06740704 0.930806   0.00178692], True Label: 1
# Predicted: [3.153610e-05 9.998134e-01 1.550261e-04], True Label: 1
# Predicted: [2.5389778e-05 9.9996138e-01 1.3254909e-05], True Label: 1
# Predicted: [1.3957210e-02 9.8544043e-01 6.0246082e-04], True Label: 1
# Predicted: [9.4156563e-01 5.7905558e-02 5.2879791e-04], True Label: 1
# Predicted: [0.0102972  0.98365307 0.00604972], True Label: 1
# Predicted: [1.9736646e-01 8.0251598e-01 1.1757662e-04], True Label: 1
# Predicted: [2.9136300e-02 9.7086132e-01 2.2975803e-06], True Label: 1
# Predicted: [0.03105519 0.95737827 0.0115664 ], True Label: 1
# Predicted: [7.6243293e-04 9.9874485e-01 4.9265352e-04], True Label: 1
# Predicted: [5.6270826e-05 9.9992108e-01 2.2639168e-05], True Label: 1
# Predicted: [8.5654324e-03 9.9143445e-01 7.4138697e-08], True Label: 1
# Predicted: [0.00529365 0.9825147  0.01219164], True Label: 1
# Predicted: [1.1072291e-01 8.8848525e-01 7.9187291e-04], True Label: 1
# Predicted: [3.952065e-03 9.960471e-01 8.015255e-07], True Label: 1
# Predicted: [1.5791669e-02 9.8418921e-01 1.9173496e-05], True Label: 1
# Predicted: [2.5623078e-03 9.9743736e-01 3.3984188e-07], True Label: 1
# Predicted: [4.0635670e-05 9.9995935e-01 1.2021753e-08], True Label: 1
# Predicted: [6.2060408e-02 9.3780661e-01 1.3290407e-04], True Label: 1
# Predicted: [8.7867320e-02 9.1213238e-01 2.9102716e-07], True Label: 1
# Predicted: [2.0439386e-02 9.7950566e-01 5.4957542e-05], True Label: 1
# Predicted: [0.16312894 0.5952227  0.24164835], True Label: 1
# Predicted: [3.6540890e-01 6.3404876e-01 5.4231123e-04], True Label: 1
# Predicted: [8.81689131e-01 1.17909275e-01 4.01568686e-04], True Label: 1
# Predicted: [0.01550078 0.9790237  0.00547553], True Label: 1
# Predicted: [1.7087117e-07 9.9999952e-01 3.8747845e-07], True Label: 1
# Predicted: [1.3461014e-02 9.8653781e-01 1.1417210e-06], True Label: 1
# Predicted: [3.5171001e-03 9.9648178e-01 1.0654747e-06], True Label: 1
# Predicted: [0.08155105 0.91682523 0.00162366], True Label: 1
# Predicted: [2.3864012e-03 9.9761176e-01 1.7402024e-06], True Label: 1
# Predicted: [1.7036098e-01 8.2963794e-01 1.0903584e-06], True Label: 1
# Predicted: [5.8982638e-04 9.9933547e-01 7.4728938e-05], True Label: 1
# Predicted: [1.4406293e-05 9.9998558e-01 4.5830568e-08], True Label: 1
# Predicted: [3.9057499e-03 9.9609357e-01 6.6307945e-07], True Label: 1
# Predicted: [1.5248156e-01 8.4703839e-01 4.8017234e-04], True Label: 1
# Predicted: [1.8758252e-02 9.8124146e-01 1.8857196e-07], True Label: 1
# Predicted: [4.8616277e-03 9.9513823e-01 9.1781075e-08], True Label: 1
# Predicted: [8.030498e-06 9.999919e-01 7.885763e-08], True Label: 1
# Predicted: [6.3757692e-04 9.9905258e-01 3.0990093e-04], True Label: 1
# Predicted: [2.0966718e-01 7.9033226e-01 5.6827417e-07], True Label: 1
# Predicted: [0.00160625 0.99728453 0.00110917], True Label: 1
# Predicted: [6.4271934e-02 9.3518955e-01 5.3853606e-04], True Label: 1
# Predicted: [0.03867407 0.3960666  0.56525934], True Label: 1
# Predicted: [2.1819908e-02 9.7808182e-01 9.8235287e-05], True Label: 1
# Predicted: [1.2632964e-02 9.8736656e-01 4.9449864e-07], True Label: 1
# Predicted: [9.3485694e-03 9.9064904e-01 2.4087819e-06], True Label: 1
# Predicted: [0.00826638 0.08131985 0.91041374], True Label: 1
# Predicted: [2.8715286e-01 7.1283883e-01 8.3109717e-06], True Label: 1
# Predicted: [1.1754357e-03 9.9829608e-01 5.2849913e-04], True Label: 1
# Predicted: [5.2816183e-03 9.9471623e-01 2.1125463e-06], True Label: 1
# Predicted: [3.2905564e-03 9.9670047e-01 8.9049272e-06], True Label: 1
# Predicted: [3.3165180e-04 9.9966443e-01 3.8782414e-06], True Label: 1
# Predicted: [0.02330698 0.9546188  0.02207408], True Label: 1
# Predicted: [9.6074793e-08 4.3484406e-06 9.9999559e-01], True Label: 2
# Predicted: [2.3579843e-04 1.5149369e-06 9.9976271e-01], True Label: 2
# Predicted: [0.00109993 0.00114829 0.9977518 ], True Label: 2
# Predicted: [1.5908023e-06 1.4473485e-04 9.9985361e-01], True Label: 2
# Predicted: [0.21212588 0.14221229 0.64566183], True Label: 2
# Predicted: [2.2996501e-04 4.0076119e-03 9.9576241e-01], True Label: 2
# Predicted: [0.00507836 0.01422277 0.9806989 ], True Label: 2
# Predicted: [0.00610051 0.03294053 0.960959  ], True Label: 2
# Predicted: [0.0088965  0.00926418 0.9818393 ], True Label: 2
# Predicted: [9.3106721e-08 7.0389242e-06 9.9999285e-01], True Label: 2
# Predicted: [4.7514134e-04 3.5805075e-05 9.9948907e-01], True Label: 2
# Predicted: [0.06352995 0.00321472 0.93325526], True Label: 2
# Predicted: [0.00468484 0.10454553 0.8907696 ], True Label: 2
# Predicted: [3.9339054e-04 7.8363868e-04 9.9882299e-01], True Label: 2
# Predicted: [0.00651689 0.07986435 0.91361874], True Label: 2
# Predicted: [0.00280105 0.00176748 0.9954314 ], True Label: 2
# Predicted: [0.00566473 0.04748543 0.9468499 ], True Label: 2
# Predicted: [5.2013178e-04 1.7345193e-03 9.9774534e-01], True Label: 2
# Predicted: [1.4883908e-04 3.6885824e-05 9.9981433e-01], True Label: 2
# Predicted: [0.01423938 0.00915918 0.9766014 ], True Label: 2
# Predicted: [3.6814701e-04 8.3196815e-04 9.9879992e-01], True Label: 2
# Predicted: [1.1755589e-04 8.2039929e-05 9.9980038e-01], True Label: 2
# Predicted: [1.1559060e-03 6.5497402e-04 9.9818915e-01], True Label: 2
# Predicted: [3.0248304e-04 1.6851696e-01 8.3118051e-01], True Label: 2
# Predicted: [0.00105478 0.00496047 0.99398476], True Label: 2
# Predicted: [0.47137928 0.01111394 0.5175068 ], True Label: 2
# Predicted: [0.00698874 0.00171819 0.991293  ], True Label: 2
# Predicted: [2.8004745e-04 6.9227847e-03 9.9279720e-01], True Label: 2
# Predicted: [0.01840975 0.02207075 0.9595195 ], True Label: 2
# Predicted: [0.07371637 0.8682872  0.05799646], True Label: 2
# Predicted: [4.035226e-04 2.594661e-03 9.970018e-01], True Label: 2
# Predicted: [1.3089489e-05 1.2811366e-05 9.9997413e-01], True Label: 2
# Predicted: [6.8325098e-05 1.4631478e-04 9.9978536e-01], True Label: 2
# Predicted: [0.00165358 0.01852988 0.9798165 ], True Label: 2
# Predicted: [8.8265893e-04 1.9520372e-02 9.7959697e-01], True Label: 2
# Predicted: [0.00448956 0.00267437 0.99283606], True Label: 2
# Predicted: [3.9579420e-05 4.4218297e-05 9.9991620e-01], True Label: 2
# Predicted: [0.07063463 0.00482202 0.9245433 ], True Label: 2
# Predicted: [1.5621739e-03 6.2545465e-04 9.9781239e-01], True Label: 2
# Predicted: [2.8990832e-04 5.3958144e-02 9.4575197e-01], True Label: 2
# Predicted: [0.00178599 0.01394082 0.9842732 ], True Label: 2
# Predicted: [2.5046282e-05 5.3603051e-04 9.9943894e-01], True Label: 2
# Predicted: [4.0947139e-05 2.2038940e-04 9.9973863e-01], True Label: 2
# Predicted: [3.0518673e-05 1.3056136e-04 9.9983895e-01], True Label: 2
# Predicted: [0.258485   0.13444857 0.60706645], True Label: 2
# Predicted: [0.02261093 0.12896582 0.8484232 ], True Label: 2
# Predicted: [0.03086046 0.55046326 0.41867623], True Label: 2
# Predicted: [6.3710980e-04 1.6921957e-03 9.9767071e-01], True Label: 2
# Predicted: [0.00432377 0.043773   0.9519032 ], True Label: 2
# Predicted: [2.395098e-05 4.679674e-03 9.952964e-01], True Label: 2
# Predicted: [1.0509966e-04 1.1157672e-03 9.9877912e-01], True Label: 2
# Predicted: [0.9696632  0.01557518 0.01476161], True Label: 2
# Predicted: [0.0079415  0.00875283 0.98330563], True Label: 2
# Predicted: [6.4811972e-03 4.6230698e-04 9.9305648e-01], True Label: 2
# Predicted: [3.2516662e-05 2.3234867e-05 9.9994421e-01], True Label: 2
# Predicted: [0.02626339 0.4088605  0.56487614], True Label: 2
# Predicted: [0.003755   0.10836896 0.887876  ], True Label: 2
# Predicted: [0.00197976 0.06949665 0.9285236 ], True Label: 2
# Predicted: [0.00269999 0.07254993 0.9247501 ], True Label: 2
# Predicted: [2.7926586e-04 2.6000521e-04 9.9946076e-01], True Label: 2
# Predicted: [0.01245107 0.03796607 0.9495828 ], True Label: 2
# Predicted: [6.1600059e-07 3.7902823e-06 9.9999559e-01], True Label: 2
# Predicted: [0.00623276 0.6356254  0.35814184], True Label: 2
# Predicted: [0.00122206 0.00103977 0.9977381 ], True Label: 2
# Predicted: [1.6778436e-06 1.5940411e-04 9.9983895e-01], True Label: 2
# Predicted: [0.01094068 0.10775623 0.88130313], True Label: 2
# Predicted: [0.3195895  0.2934006  0.38700992], True Label: 2
# Predicted: [0.09691121 0.04626657 0.8568222 ], True Label: 2
# Predicted: [0.32880685 0.0068026  0.6643905 ], True Label: 2
# Predicted: [0.00253103 0.11358234 0.8838866 ], True Label: 2
# Predicted: [0.13671228 0.04839502 0.8148927 ], True Label: 2
# Predicted: [0.06651781 0.0633547  0.8701275 ], True Label: 2
# Predicted: [0.74335146 0.15582551 0.10082311], True Label: 2
# Predicted: [1.8451009e-04 3.9795050e-03 9.9583602e-01], True Label: 2
# Predicted: [0.02840038 0.13060896 0.8409906 ], True Label: 2
# Predicted: [5.6280507e-05 6.2371510e-05 9.9988139e-01], True Label: 2
# Predicted: [8.2852272e-04 1.1677444e-02 9.8749405e-01], True Label: 2
# Predicted: [0.04745138 0.15421897 0.7983296 ], True Label: 2
# Predicted: [0.07932738 0.02007509 0.90059745], True Label: 2
# Predicted: [2.4814615e-03 6.5873734e-05 9.9745268e-01], True Label: 2
# Predicted: [0.26594907 0.04417947 0.6898715 ], True Label: 2
# Predicted: [0.63582206 0.09129127 0.27288657], True Label: 2
# Predicted: [0.8145301  0.01053951 0.17493051], True Label: 2
# Predicted: [0.00234641 0.00133289 0.9963207 ], True Label: 2
# Predicted: [0.00876535 0.00176606 0.98946863], True Label: 2
# Predicted: [0.00477421 0.05179152 0.94343424], True Label: 2
# Predicted: [8.5877656e-04 3.2251392e-04 9.9881870e-01], True Label: 2
# Predicted: [0.00958612 0.00146779 0.98894614], True Label: 2
# Predicted: [5.6950259e-04 1.4548353e-03 9.9797565e-01], True Label: 2
# Predicted: [7.205207e-04 6.393945e-04 9.986401e-01], True Label: 2
# Predicted: [4.8529157e-05 1.5047244e-03 9.9844676e-01], True Label: 2
# Predicted: [4.4759854e-05 5.0304654e-05 9.9990487e-01], True Label: 2
# Predicted: [0.001226  0.4826362 0.5161378], True Label: 2
# Predicted: [4.1465953e-02 5.1622192e-04 9.5801783e-01], True Label: 2
# Predicted: [3.1459010e-03 9.0906909e-04 9.9594504e-01], True Label: 2
# Predicted: [3.3142715e-04 3.0061200e-01 6.9905663e-01], True Label: 2
# Predicted: [0.89452285 0.10052595 0.00495114], True Label: 2
# Predicted: [0.20514847 0.26828334 0.52656823], True Label: 2
# Predicted: [0.02421319 0.54233444 0.43345237], True Label: 2
# Predicted: [0.02583797 0.18068941 0.7934726 ], True Label: 2
# Predicted: [0.00556858 0.00641852 0.9880129 ], True Label: 2
# Predicted: [0.00887912 0.0723916  0.91872925], True Label: 2
# Predicted: [0.00203524 0.0019966  0.9959682 ], True Label: 2
# Predicted: [0.0200704  0.00205922 0.97787035], True Label: 2
# Predicted: [0.21704319 0.35887617 0.42408067], True Label: 2
# Predicted: [0.20962799 0.06220619 0.72816575], True Label: 2
# Predicted: [0.07879327 0.12654337 0.79466337], True Label: 2
# Predicted: [0.0158884  0.00395133 0.9801603 ], True Label: 2
# Predicted: [0.11023463 0.05865934 0.83110607], True Label: 2
# Predicted: [0.00158774 0.00564996 0.99276227], True Label: 2
# Predicted: [9.4518121e-03 1.7345749e-04 9.9037474e-01], True Label: 2
# Predicted: [0.01426309 0.01532782 0.97040904], True Label: 2
# Predicted: [0.00184047 0.74591553 0.252244  ], True Label: 2
# Predicted: [0.00216114 0.00793802 0.9899009 ], True Label: 2
# Predicted: [6.8634356e-05 1.7139316e-04 9.9975997e-01], True Label: 2
# Predicted: [0.9367123  0.0447014  0.01858625], True Label: 2
# Predicted: [0.0410122  0.09088289 0.86810493], True Label: 2
# Predicted: [4.4228109e-03 5.5477617e-04 9.9502242e-01], True Label: 2
# Predicted: [9.184174e-05 7.786291e-04 9.991296e-01], True Label: 2
# Predicted: [0.10899757 0.7897957  0.1012067 ], True Label: 2
# Predicted: [0.00410636 0.00377548 0.9921182 ], True Label: 2
# Predicted: [0.03953616 0.9213014  0.0391624 ], True Label: 2
# Predicted: [8.8673896e-06 6.3984089e-06 9.9998474e-01], True Label: 2
# Predicted: [0.01505646 0.0013793  0.98356426], True Label: 2
# Predicted: [0.00526488 0.09384803 0.9008871 ], True Label: 2
# Predicted: [0.08247171 0.03307076 0.8844575 ], True Label: 2
# Predicted: [0.00506619 0.00328332 0.9916504 ], True Label: 2
# Predicted: [0.73974407 0.00684176 0.25341415], True Label: 2
# Predicted: [0.00432433 0.00408221 0.9915935 ], True Label: 2
# Predicted: [1.3548753e-04 4.3984206e-04 9.9942470e-01], True Label: 2
# Predicted: [3.3262096e-04 5.1797263e-04 9.9914944e-01], True Label: 2
# Predicted: [9.9429465e-04 3.5829153e-03 9.9542278e-01], True Label: 2
# Predicted: [0.01214096 0.37086546 0.6169936 ], True Label: 2
# Predicted: [1.36359865e-02 4.53469518e-04 9.85910535e-01], True Label: 2
# Predicted: [0.05743153 0.00883599 0.9337325 ], True Label: 2
# Predicted: [0.09998258 0.2739744  0.626043  ], True Label: 2
# Predicted: [0.08663546 0.00349155 0.909873  ], True Label: 2
# Predicted: [9.0206735e-04 5.2131451e-04 9.9857664e-01], True Label: 2
# Predicted: [4.8603538e-06 1.3781677e-05 9.9998140e-01], True Label: 2
# Predicted: [0.19281286 0.06673883 0.74044836], True Label: 2
# Predicted: [0.01542715 0.15060648 0.8339663 ], True Label: 2
# Predicted: [0.00148098 0.00257161 0.9959474 ], True Label: 2
# Predicted: [0.29412714 0.04424997 0.6616229 ], True Label: 2
# Predicted: [0.01069672 0.2928868  0.6964165 ], True Label: 2
# Predicted: [0.00432362 0.00154831 0.9941281 ], True Label: 2
# Predicted: [0.03147965 0.6210957  0.3474246 ], True Label: 2
# Predicted: [0.01277931 0.98322177 0.00399895], True Label: 2
# Predicted: [3.0155181e-05 3.3494955e-04 9.9963486e-01], True Label: 2
# Predicted: [0.00409472 0.2610163  0.734889  ], True Label: 2
# Predicted: [2.4604597e-03 6.5756991e-05 9.9747378e-01], True Label: 2
# Predicted: [0.5349147  0.18361558 0.28146967], True Label: 2
# Predicted: [6.684041e-04 7.331604e-04 9.985984e-01], True Label: 2
# Predicted: [0.0877577  0.08345087 0.8287915 ], True Label: 2
# Predicted: [0.551002   0.44727886 0.00171911], True Label: 2
# Predicted: [9.691519e-04 5.455286e-04 9.984854e-01], True Label: 2
# Predicted: [0.00249884 0.06389925 0.93360186], True Label: 2
# Predicted: [0.1432118  0.48171583 0.3750724 ], True Label: 2
# Predicted: [0.23544283 0.03000673 0.7345505 ], True Label: 2
# Predicted: [0.12515555 0.07439956 0.8004449 ], True Label: 2
# Predicted: [0.773656   0.01906512 0.20727885], True Label: 2
# Predicted: [0.00125291 0.00215866 0.99658847], True Label: 2
# Predicted: [8.8181958e-05 1.7754943e-03 9.9813628e-01], True Label: 2
# Predicted: [0.0775521  0.20730503 0.71514285], True Label: 2
# Predicted: [0.00167473 0.06597383 0.9323514 ], True Label: 2
# Predicted: [0.00147281 0.00318093 0.99534625], True Label: 2
# Predicted: [0.5100285  0.01807679 0.4718947 ], True Label: 2
# Predicted: [2.4689728e-04 1.4511444e-02 9.8524171e-01], True Label: 2
# Predicted: [1.7337431e-04 7.2033159e-02 9.2779350e-01], True Label: 2
# Predicted: [6.5962225e-04 7.5011976e-02 9.2432839e-01], True Label: 2
# Predicted: [0.06775821 0.0025332  0.9297086 ], True Label: 2
# Predicted: [0.03931067 0.36783057 0.59285873], True Label: 2
# Predicted: [7.017963e-05 7.995971e-03 9.919338e-01], True Label: 2
# Predicted: [1.5160785e-04 7.0347311e-04 9.9914491e-01], True Label: 2

# %%
cm = confusion_matrix(true_labels, class_predictions)

class_labels = ['Benign', 'Malignant', 'Normal']

# Plot confusion matrix using heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
